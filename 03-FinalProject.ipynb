# %% [markdown]
# # COGS 108 - Mainstream Music Homogeneity Before and After Streaming
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [ X ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# #### Background and Our Motivation
# This project investigates whether or not the introduction of streaming services has led to the homogenization of mainstream popular music. We were interested in understanding the difference between music in the pre-streaming era (2000-2012) and the post-streaming era (2013-2026), particularly in relation to the Billboard top songs each month. Prior discussions about streaming’s effect on music suggest that it may have led to popular songs getting shorter and possibly more similar, which motivated us to explore whether popular music really has changed in a meaningful way. With streaming platforms and algorithmic recommendations playing a larger role in music distribution and discovery in this post-streaming era (2013-2026), we aim to determine whether or not these changes in the main vehicle that society uses to listen to songs has influenced the diversity of characteristics found in popular music.
# #### Data and Methods
# To explore this question, we combined multiple datasets, including Billboard Hot 50 chart rankings and Spotify audio feature metadata. From the Billboard data, we extracted the top-three songs from each year and matched them with Spotify’s audio features such as danceability, energy, valence, acousticness, instrumentalness, tempo, loudness, and speechiness. We also computed a musical diversity score using the data. We then performed an exploratory data analysis to examine trends and variability in these features across the pre-streaming and post-streaming eras. This included visualizing feature distributions using histograms and boxplots, analyzing year-by-year trends in average feature values, and examining correlations between different musical attributes. We also compared the spread and variance of each feature across the two eras to evaluate potential changes in musical diversity. We computed an overall musical diversity score for both eras by aggregating the variability of all analyzed features into a single comparable metric, allowing us to determine whether mainstream music in one era demonstrated greater or lesser variability than the other. Finally, we also performed an analysis of the change in lyric sentiment between the pre-streaming and post-streaming eras.
# #### Major Findings
# Our findings from our conducted research suggest that while several musical features have gone through a statistically significant change in the post-streaming era, such as increased energy, louder production, shorter song durations, and increased explicitness, these changes are not indicative of a major shift in the overall variability of musical features among popular music. The variability across many features remains relatively broad, with very similar musical diversity scores (0.7098 vs. 0.7085), suggesting that while streaming platforms and algorithms may influence popular music trends, they don’t necessarily lead to a complete homogenization of mainstream music.
# #### Conclusion and Implications
# Overall, our analysis provides insight into how new technology and the changes that come from adopting new technology can shape the sound of popular music over time. Since the diversity of popular music has mostly stayed the same, with features such as danceability, speechiness, and lyric sentiment,  proving to have stayed mostly consistent, with only some features having a marked change, such as song duration and explicitness, we can conclude that popular music continues to maintain musical diversity, even throughout the overhaul that was algorithm-driven streaming. Though this relationship between popular music and musical diversity can definitely be further explored in lots of different ways, a preliminary explanation for the unchanging nature of musical diversity could be that society has remained diverse, and it makes sense that popular music has also remained diverse, as it is society that drives popular music.

# %% [markdown]
# ## Authors
#
# - Angel Thakur - Data wrangling, EDA Section 2
# - Esha Shah - Data curation, Experimental Investigation/EDA Section 1
# - Lily Fischer - Writing - original draft, Writing - review & editing
# - Damarys Bautista Quezada - Writing background/analysis
# - Elnur Tuman - Writing background/analysis, Abstract

# %% [markdown]
# ## Research Question

# %% [markdown]
# To what extent has the variability in mainstream music, measured by the difference in features like tempo, key, explicitness, energy, and sentiment of annual Billboard Top 50 songs, increased or decreased between the streaming era (2013-2026) relative to the pre-streaming era (2000-2012)?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# As digitalization has rapidly advanced, no stone has been left unturned. The way we listen to music has been one of the biggest changes, progressing from physical cassettes, records, and CDs to singular devices that hold hundreds of millions of tracks. This unparalleled access to music has not come lightly. Ever since digitalization reached music in the 2010s, consumers have been able to purchase or subscribe to a streaming platform to gain access to a wide variety of songs readily available to them. Since the release of streaming platforms like Spotify and Apple Music, the barrier of entry to consume and release music has lowered exponentially.
#
# Perhaps one of the clearest signs of how music has changed is the change in the average length of music over time, which has decreased by more than 30 seconds. Many of the top songs of the past few years have clocked in at under three minutes, a clear departure from longer music. This is most likely attributable to the differences streaming makes in song structure. According to music information scientists at Spotify, Nicola Montecchio, Pierre Roy, and François Pachet, there is a correlation between skipping and song structure: users are more likely to skip songs before they have reached 30 seconds. Since streaming services only pay artists for “plays” and “plays” only count if a song has been played for longer than 30 seconds, it stands to reason that many artists and songwriters have focused their energy towards creating catchy music that’s interesting enough to capture attention in the beginning, but short enough that listeners won’t get bored and skip too early, leaving artists without their hard-earned revenue.
#
# A study by NYU PhD Alumni in the Wall Street Journal supports the Spotify scientist's findings, sharing how streaming has encouraged the practice of shortening songs to  catch the listener's attention as quickly as possible. They cite an interview with Grammy-winning producer and performer Mark Ronson to highlight the reason behind the practice: “All your songs have to be under three minutes and 15 seconds because if people don’t listen to them all the way to the end, they go into this ratio of ‘non-complete heard,’ which sends your Spotify rating down,” (Ronson in Rosenblatt). They further build on this phenomenon by highlighting how, though song length has decreased, album length has increased. This trend has been seen largely because when an artist releases a new album, fans often listen to the entire collection, generating more revenue per song. The widespread nature of this practice leads us to theorize that song structure has become a notably more homogenized aspect of music due to streaming's influence.
#
# In a previous study from Tilburg University, the impact of streaming services on homogenized mainstream music is mixed. Researchers Knox and Datta look at the supply and demand side of the industry, focusing on the “acoustic diversity” of a given song: the pitch, loudness, valence, tempo, and duration. In the early beginnings of platforms like Napster, an illegal music sharing platform, YouTube, and Spotify, artists were able to easily create and distribute their music to a large audience in a way that had not been seen before. Musicians tended to mimic each other in the early stages of the new widespread distribution of music, leading to an initial decrease in diversity in music quality. However, when streaming services like Spotify became more popular, algorithms in place were able to provide new recommendation systems and search tools that enabled listeners to discover a vast amount of music readily available to them. From a demand standpoint, consumers have more choices of music selection available to them, thus allowing for more diversity within their consumption. Thus, despite its initial dip, Knox and Datta's study found a weak, steady increase in acoustic diversity since the release of streaming platforms due to the large catalog of recorded music available.
#
# Overall, this research highlighted how recommendation algorithms and user skips have become imperative considerations in the music-making process. The more a song appeals to an algorithm or the widest audience possible, the more streams a song has, and the more money it makes. In this project, we’d like to explore whether or not these factors have led to music becoming more homogenized from the pre-streaming (2000-2012) to the post-streaming (2013-2026) eras. Our definition of homogeneity will include several features, including acousticness, danceability, energy, instrumentalness, loudness, speechiness, tempo, valence, key, explicitness, duration, and lyric sentiment. Energy measures the "danceability" and animation of a given song; faster tempos and louder volumes connote higher scales of danceability and activity in a track, whereas softer, quieter volumes and slower tempos connote lower scales of energy. Valence describes the musical positivity; higher scales of valence include upbeat, happier, and euphoric music, while lower values will include more moody, sadder, and tense musical qualities. High acousticness will include songs that sound organically produced physically by humans with instruments, and lower values of acousticness will include songs that sound electronically produced, including techno-music. Instrumentalness highlights how many words are in a given track. A song with many lyrics will be graded lower on the instrumentalness scale, whereas tracks with mostly instrumental portions with very few lyrics and vocals will be graded higher on the scale. Lyric sentiment will be classified into positive and negative categories by the NLTK VADER tool. We aim to measure the standard deviation and variance of these values within both time epochs in order to determine homogeneity differences.
#
# Rosenblatt, Bill. “Streaming Is Changing the Sound of Music.” The Wall Street Journal, 15 Sept. 2023, www.wsj.com/arts-culture/music/streaming-is-changing-the-sound-of-music-182dc907. Accessed 4 Feb. 2026.
#
# Montecchio, Nicola, et al. “The Skipping Behavior of Users of Music Streaming Services and Its Relation to Musical Structure.” PLOS ONE, edited by Jichang Zhao, vol. 15, no. 9, Sept. 2020, p. e0239418. DOI.org, https://doi.org/10.1371/journal.pone.0239418.
#
# Knox, G., and H. Datta. “Streaming Services and the Homogenization of Music Consumption.” Tilburg University, 23 July 2020, https://research.tilburguniversity.edu/en/publications/streaming-services-and-the-homogenization-of-music-consumption/.

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We hypothesize that songs from the years 2013-2026, which would be considered the streaming era, will exhibit less variability in measurable factors such as danceability, energy valence, acousticness, instrumentalness, tempo, duration, loudness, key/mode, explicitness, and speechness when comparing them to songs from 2000-2012, which would be the pre-streaming era. We theorize that it is largely because of two reasons. The first is because of the rise of streaming services as a whole and how the industry is run. Streaming services are operated as a business that pits artists against each other in a popularity contest. More streams mean an artist's music is pushed out more, which means more money for the artist and exponentially more for the business. This also encourages streaming services to promote music that appeals to the broadest audience, as it generates the most revenue for them. Additionally, corporations have a direct hand in the creation of the music itself. Music labels that govern artists want to maximize profits and popularity of an their music, which makes them push for the production of music that is broader, more generic, and more formulaic to appeal to more listeners. They judge music not by its authenticity, but by the number of albums sold and streaming popularity, ultimately leading to more homogeneous music industry as a whole.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# - Dataset #1:
#
#     - Dataset Name: BillBoard Hot100 Annual Top 50
#     - Link to the dataset: Scraped from Wikipedia
#     - Number of observations: 3900
#     - Number of variables: 2
#     - Description of the variables most relevant to this project: Position - the numbered ranking on the annual top 50 list. Name: the name of the song at the indicated position.
#     - Descriptions of any shortcomings this dataset has with repsect to the project: Only includes Billboard's rankings, which are mainstream media centralized to the United States and North America.
#
# - Dataset #2:
#     - Dataset Name: 160k Spotify songs from 1921 to 2020 (Sorted)
#     - Link to the dataset: https://github.com/fcpercival/spotify-data-sorted
#     - Number of observations: 160,000+
#     - Number of variables: 12
#     - Description of the variables most relevant to this project: Danceability (unitless, 0–1) estimates how suitable a track is for dancing. Energy (0–1) measures intensity and activity. Valence (0–1) describes musical positivity. Acousticness (0–1) estimates the likelihood a track is acoustic rather than electronically produced. Instrumentalness (0–1) predicts whether a track contains vocals Tempo is measured in beats per minute (BPM) Duration is given in milliseconds; dividing by 1000 converts to seconds. Loudness is measured in decibels (dB) Key is encoded as an integer 0–11 representing the 12 pitch classes (C through B) Mode indicates major (1) or minor (0). Speechiness (0–1) measures the presence of spoken words
#     - Descriptions of any shortcomings this dataset has with repsect to the project: Dataset doesnt have data past 2020 and can reflect biases from Spotify's reccomendation algorithms.
#
# - Dataset #3:
#
#
#     - Dataset Name: Genius Lyrics
#     - Link to the dataset: https://docs.genius.com/
#     - Number of observations: 1.7 million+
#     - Number of variables: 30+
#     - Description of the variables most relevant to this project: Song Name - name of the song. Artist - artist of the song. Lyrics -  all the lyrics to the song
#     - Descriptions of any shortcomings this dataset has with repsect to the project: Does not include any data that can be used to analyze the seniment of song lyrics. This functionality must be sourced from an external tool.

# %% [markdown]
# ### Dataset #1 - Billboard Annual Top 50
#
# **NOTE** The final report should not be overly long.  If this wrangling step is huge and complicated you should remove these sections from the final report and replace them with a statement like "To see the code responsible for wrangling the data see `01-DataCheckpoint.ipynb`. From here on we will simply load the processed data for further analysis"

# %%
# run %pip install lxml if not already

# %%
import requests
import pandas as pd
import time
from io import StringIO

start_year = 2000
end_year = 2025

all_years = []

headers = {
    "User-Agent": "Mozilla/5.0"
}

for year in range(start_year, end_year + 1):
    try:
        url = f"https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_{year}"
        
        response = requests.get(url, headers=headers)
        response.raise_for_status()

        html = StringIO(response.text)
        tables = pd.read_html(html)

        for table in tables:
            if "Title" in table.columns or "Song" in table.columns:
                df = table
                break

        df = df.head(10).copy()

        df = df.iloc[:, -2:]
        
        df.columns = ["song", "artist"]
        
        df["year"] = year
        
        df = df[["year", "song", "artist"]]
        
        df.columns = [str(col).lower() for col in df.columns]

        if "title" in df.columns:
            df = df.rename(columns={"title": "song"})
        if "artist(s)" in df.columns:
            df = df.rename(columns={"artist(s)": "artist"})

        if "song" not in df.columns:
            df.rename(columns={df.columns[1]: "song"}, inplace=True)
        if "artist" not in df.columns:
            df.rename(columns={df.columns[2]: "artist"}, inplace=True)

        all_years.append(df)

        print(f"Finished {year}")

    except Exception as e:
        print(f"Skipped {year}: {e}")

final_df = pd.concat(all_years, ignore_index=True)

print(final_df.head())
# Out:
# Finished 2000
# Finished 2001
# Finished 2002
# Finished 2003
# Finished 2004
# Finished 2005
# Finished 2006
# Finished 2007
# Finished 2008
# Finished 2009
# Finished 2010
# Finished 2011
# Finished 2012
# Finished 2013
# Finished 2014
# Finished 2015
# Finished 2016
# Finished 2017
# Finished 2018
# Finished 2019
# Finished 2020
# Finished 2021
# Finished 2022
# Finished 2023
# Finished 2024
# Finished 2025
#    year                   song                             artist
# 0  2000              "Breathe"                         Faith Hill
# 1  2000               "Smooth"       Santana featuring Rob Thomas
# 2  2000          "Maria Maria"  Santana featuring The Product G&B
# 3  2000         "I Wanna Know"                                Joe
# 4  2000  "Everything You Want"                   Vertical Horizon

# %%
final_df.to_csv('data/01-interim/billboard_top10_annual')

top10_yearly = final_df

def determine_era(year):
    if year < 2013:
        return "pre"
    else:
        return "post"

top10_yearly["era"] = top10_yearly["year"].apply(determine_era)

display(top10_yearly.isna().sum())
# Out:
# year      0
# song      0
# artist    0
# era       0
# dtype: int64

# %%
top10_yearly["song"] = top10_yearly["song"].astype("string")
top10_yearly["artist"] = top10_yearly["artist"].astype("string")
print(top10_yearly.dtypes)
# Out:
# year               int64
# song      string[python]
# artist    string[python]
# era               object
# dtype: object

# %%
#artist cleanup (will be applied to Spotify 160k later as well)
import re

def normalize_artists(artist_string):
    if pd.isna(artist_string):
        return artist_string
    artist_string = artist_string.lower()
    artist_string = re.sub(r'featuring|feat\.?|with|&| x | and ', ',', artist_string) 
    artist_string = re.sub(r'\s*,\s*', ',', artist_string)
    artist_string = re.sub(r',+', ',', artist_string)
    artist_list = artist_string.split(',')
    artist_list = [a.strip() for a in artist_list if a.strip()]
        
    return ",".join(artist_list)

# %%
#apply artist cleaning
top10_yearly["artists"] = top10_yearly["artist"].apply(normalize_artists)
top10_yearly.drop(columns=['artist'], inplace=True)

top10_yearly
# Out:
#      year                   song   era                    artists
# 0    2000              "Breathe"   pre                 faith hill
# 1    2000               "Smooth"   pre         santana,rob thomas
# 2    2000          "Maria Maria"   pre    santana,the product g,b
# 3    2000         "I Wanna Know"   pre                        joe
# 4    2000  "Everything You Want"   pre           vertical horizon
# ..    ...                    ...   ...                        ...
# 255  2025     "Beautiful Things"  post               benson boone
# 256  2025             "Ordinary"  post                alex warren
# 257  2025      "I Had Some Help"  post  post malone,morgan wallen
# 258  2025                 "APT."  post            rosé,bruno mars
# 259  2025       "Pink Pony Club"  post              chappell roan
#
# [260 rows x 4 columns]

# %%
top10_2000_2013 = top10_yearly[top10_yearly["era"] == "pre"]
top10_2000_2013.shape
# Out:
# (130, 4)

# %%
top10_2014_2026 = top10_yearly[top10_yearly["era"] == "post"]
top10_2014_2026.shape
# Out:
# (130, 4)

# %% [markdown]
# ### Dataset #2 - 160K Spotify Songs (1921-2020)
#
# https://github.com/fcpercival/spotify-data-sorted
#
# The 160K Spotify Songs (1921–2020) is a large music metadata collection derived from Spotify’s Web API. It contains roughly 160,000 tracks and includes artist information, genre labels, release year, and several audio features.
#
# The most important metrics are Spotify’s audio features, which are standardized numeric descriptors. Danceability (unitless, 0–1) estimates how suitable a track is for dancing. Values closer to 1 indicate more danceable songs. Energy (0–1) measures intensity and activity; higher values correspond to louder and faster tracks. Valence (0–1) describes musical positivity. Higher values sound happier or more euphoric, while lower values tend to sound sadder or more tense. Acousticness (0–1) estimates the likelihood a track is acoustic rather than electronically produced. Instrumentalness (0–1) predicts whether a track contains vocals; values above ~0.5 suggest mostly instrumental music. These features are probabilities or model outputs rather than physical measurements, so they are relative indicators rather than exact physical quantities.
#
# Several features are expressed in real physical units. Tempo is measured in beats per minute (BPM); most contemporary pop songs fall roughly between 90–130 BPM, while extreme values (e.g., >200 BPM) indicate very fast genres like speed metal or certain electronic styles. Duration is given in milliseconds; dividing by 1000 converts to seconds. Loudness is measured in decibels (dB), typically ranging from about −60 dB (very quiet) to 0 dB (maximum digital level). Key is encoded as an integer 0–11 representing the 12 pitch classes (C through B), and mode indicates major (1) or minor (0). Speechiness (0–1) measures the presence of spoken words; values above ~0.66 are likely spoken word (e.g., podcasts, rap verses heavy in speech), while values below ~0.33 are more purely musical. These metrics allow analysis of musical style, mood, production trends, and historical changes over time.
#
# The primary concern with bias in this dataset is derived from the fact that the data is taken from Spotify’s catalog and recommendation algorithms, meaning it reflects Spotify’s licensing agreements and popularity trends, not a perfectly representative sample of all music ever recorded. Earlier decades (e.g., 1920s–1950s) are likely underrepresented and skewed toward recordings that have been digitized and re-released, which may also show biases. Furthermore, the data does not consist of music from 2020-2026, which is a large segment of the time period we are analyzing for post-streaming. as above, add any more copies of this that you need to given how many datasets you have

# %%
import pandas as pd
import os
from sklearn.preprocessing import StandardScaler, MinMaxScaler

df = pd.read_csv("data/00-raw/music-data.csv")
drops = ['liveness', 'popularity']
df = df.drop(columns=drops)
print(df.columns)
print(df.isnull().sum())

df["duration_min"] = df["duration_ms"] / 60000
df = df.drop(columns=["duration_ms"])

features = [
    "acousticness",
    "danceability",
    "energy",
    "instrumentalness",
    "speechiness",
    "tempo",
    "valence",
    "duration_min"
]

X = df[features].copy()
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns=features)

loudness_scaled = MinMaxScaler().fit_transform(df[["loudness"]])

df_scaled = X_scaled_df.copy()
df_scaled["loudness"] = loudness_scaled
df[df_scaled.columns] = df_scaled

folder_name = 'data/01-interim'
file_name = 'filtered_feature_map.csv'
full_path = os.path.join(folder_name, file_name)

if not os.path.exists(folder_name):
    os.makedirs(folder_name, exist_ok=True)

df.to_csv(full_path, index=False)
# Out:
# Index(['id', 'name', 'artists', 'duration_ms', 'release_date', 'year',
#        'acousticness', 'danceability', 'energy', 'instrumentalness',
#        'loudness', 'speechiness', 'tempo', 'valence', 'mode', 'key',
#        'explicit'],
#       dtype='object')
# id                  0
# name                0
# artists             0
# duration_ms         0
# release_date        0
# year                0
# acousticness        0
# danceability        0
# energy              0
# instrumentalness    0
# loudness            0
# speechiness         0
# tempo               0
# valence             0
# mode                0
# key                 0
# explicit            0
# dtype: int64

# %%
df
# Out:
#                             id  \
# 0       0gNNToCW3qjabgTyBSjt3H
# 1       0tMgFpOrXZR6irEOLNWwJL
# 2       2ZywW3VyVx6rrlrX75n3JB
# 3       6DdWA7D1o5TU2kXWyCLcch
# 4       3vMmwsAiLDCfyc1jl76lQE
# ...                        ...
# 169902  4KiYPYpm4ultIp247ftPlI
# 169903  42tFTth2jcF7iSo0RBjfJF
# 169904  6XP9L7di5JnOc9WaeAW8oe
# 169905  3Gpdzw72aBVJSrm5J1leVK
# 169906  2p5DfmIUTLH79elmaSCCR5
#
#                                                      name  \
# 0                               !Que Vida! - Mono Version
# 1                                                    "40"
# 2                                             "40" - Live
# 3                                  "40" - Remastered 2008
# 4                                  "40" - Remastered 2008
# ...                                                   ...
# 169902                                 텅 빈 마음 Empty Heart
# 169903                                     피카부 Peek-A-Boo
# ...

# %% [markdown]
# The following section cleans up the Spotify 160k dataset to only include those in out Billboard Top 50 Annual sample set

# %%
import pandas as pd
import re
import ast

def clean_title(title):
    if pd.isna(title):
        return title
    
    title = title.lower()
    
    # remove quotes
    title = title.replace('"', '')
    title = title.replace("'", "")
    
    # remove parentheses content
    title = re.sub(r"\(.*?\)", "", title)
    
    # remove dash versions
    title = re.sub(r"-.*", "", title)
    
    # remove punctuation
    title = re.sub(r"[^\w\s]", "", title)
    
    return title.strip()

def clean_spotify_artists(artist_string):
    if pd.isna(artist_string):
        return None
    
    # convert string list → python list
    artist_list = ast.literal_eval(artist_string)
    
    # lowercase and strip
    artist_list = [a.lower().strip() for a in artist_list]
    
    return ",".join(artist_list)

# %%
pre_billboard = pd.read_csv("data/02-processed/pre_streaming_top10_annual")
post_billboard = pd.read_csv("data/02-processed/post_streaming_top10_annual")

pre_billboard["song"].dtype
# Out:
# dtype('O')

# %%
pre_billboard["song_clean"] = pre_billboard["song"].apply(clean_title)
post_billboard["song_clean"] = post_billboard["song"].apply(clean_title)
df["song_clean"] = df["name"].apply(clean_title)

df["artist_clean"] = df["artists"].apply(normalize_artists)
df["artist_clean"] = df["artists"].apply(clean_spotify_artists)

# %%
spotify_df = df
spotify_df
# Out:
#                             id  \
# 0       0gNNToCW3qjabgTyBSjt3H
# 1       0tMgFpOrXZR6irEOLNWwJL
# 2       2ZywW3VyVx6rrlrX75n3JB
# 3       6DdWA7D1o5TU2kXWyCLcch
# 4       3vMmwsAiLDCfyc1jl76lQE
# ...                        ...
# 169902  4KiYPYpm4ultIp247ftPlI
# 169903  42tFTth2jcF7iSo0RBjfJF
# 169904  6XP9L7di5JnOc9WaeAW8oe
# 169905  3Gpdzw72aBVJSrm5J1leVK
# 169906  2p5DfmIUTLH79elmaSCCR5
#
#                                                      name  \
# 0                               !Que Vida! - Mono Version
# 1                                                    "40"
# 2                                             "40" - Live
# 3                                  "40" - Remastered 2008
# 4                                  "40" - Remastered 2008
# ...                                                   ...
# 169902                                 텅 빈 마음 Empty Heart
# 169903                                     피카부 Peek-A-Boo
# ...

# %%
billboard_all = pd.concat([pre_billboard, post_billboard], ignore_index=True)
print(billboard_all["era"].value_counts())
# Out:
# era
# pre     130
# post    130
# Name: count, dtype: int64

# %%
billboard_all.rename(columns={"artists" :"artist_clean"}, inplace=True)

# %%
spotify_df['release_date'] = pd.to_datetime(
    spotify_df['release_date'],
    format='%m/%d/%y',
    errors='coerce'  # invalid parsing becomes NaT
)
spotify_df['release_year'] = spotify_df['release_date'].dt.year
billboard_all['year'] = pd.to_numeric(billboard_all['year'], errors='coerce')

# %%
merged_df = billboard_all.merge(
    spotify_df,
    left_on='song_clean',
    right_on='song_clean',
    how='inner',
    suffixes=('_billboard','_spotify')
)
merged_df
# Out:
#       Unnamed: 0  year_billboard                  song   era  \
# 0              0            2000             "Breathe"   pre
# 1              0            2000             "Breathe"   pre
# 2              0            2000             "Breathe"   pre
# 3              0            2000             "Breathe"   pre
# 4              0            2000             "Breathe"   pre
# ...          ...             ...                   ...   ...
# 1215         253            2025        "Lose Control"  post
# 1216         253            2025        "Lose Control"  post
# 1217         254            2025  "Birds of a Feather"  post
# 1218         255            2025    "Beautiful Things"  post
# 1219         256            2025            "Ordinary"  post
#
#      artist_clean_billboard          song_clean                      id  \
# 0                faith hill             breathe  06L1apH8kLF47dbhZ4Zg9A
# 1                faith hill             breathe  0uKrhHBDUQ4w5fv4qwOubP
# ...

# %%
merged_df['year_diff'] = (merged_df['release_year'] - merged_df['year_billboard']).abs()
merged_df = merged_df.sort_values('year_diff').drop_duplicates(subset=['song_clean'], keep='first')

# %%
print(len(billboard_all))
print(len(merged_df))
# Out:
# 260
# 228

# %%
merged_df
# Out:
#       Unnamed: 0  year_billboard                   song   era  \
# 604          125            2012        "Glad You Came"   pre
# 537          109            2010     "Break Your Heart"   pre
# 533          108            2010             "Dynamite"   pre
# 1045         203            2020      "Don't Start Now"  post
# 1047         204            2020             "Rockstar"  post
# ...          ...             ...                    ...   ...
# 1217         254            2025   "Birds of a Feather"  post
# 64            10            2001  "Hanging by a Moment"   pre
# 219           44            2004     "The Way You Move"   pre
# 567          118            2011    "Moves like Jagger"   pre
# 1210         242            2024     "Beautiful Things"  post
#
#            artist_clean_billboard           song_clean  \
# 604                    the wanted        glad you came
# 537            taio cruz,ludacris     break your heart
# ...

# %%
def determine_era(year):
    if year < 2013:
        return "pre"
    else:
        return "post"

merged_df["era"] = merged_df["year_billboard"].apply(determine_era)
merged_df.to_csv("data/01-interim/merged-spotify-billboard", index=False)

display(top10_yearly.isna().sum())
# Out:
# year       0
# song       0
# era        0
# artists    0
# dtype: int64

# %%
pre_streaming_features = merged_df[merged_df["era"] == 'pre']
post_streaming_features = merged_df[merged_df["era"] == 'post']

pre_streaming_features.shape
# Out:
# (129, 26)

# %%
post_streaming_features.shape
# Out:
# (99, 26)

# %%
pre_streaming_features.drop(columns = ["Unnamed: 0"], inplace = True)
post_streaming_features.drop(columns = ["Unnamed: 0"], inplace = True)

# %%
post_streaming_features.to_csv("data/02-processed/post_streaming_features")
pre_streaming_features.to_csv("data/02-processed/pre_streaming_features")

# %% [markdown]
# ### Dataset #3: Genius Lyrics Dataset
#
# For this project, we sourced lyrics from the Genius Lyrics Database, filtering entries to match our selected sample of Billboard songs. The Genius database is a crowdsourced repository containing over 8 million lyrics, making it the largest publicly available resource for lyrical and musical knowledge. Contributions are often verified by the artists themselves, ensuring a high degree of accuracy not only for the lyrics but also for the annotations and analyses associated with each song. Using the LyricsGenius Python client, we retrieved lyrics corresponding to our sample of songs from both the pre- and post-streaming eras, enabling a consistent and structured dataset for analysis. These lyrics form the basis for our exploration of lyrical features across the eras of interest, focusing primarily on emotional sentiment.
#
# https://genius.com/api-clients

# %%
import os
import pandas as pd
import re
os.environ["GENIUS_API_TOKEN"] = "api token here"

print("Genius API token set successfully!")
# Out:
# Genius API token set successfully!

# %%
#run pip install lyricsgenius first if you do not have it
import lyricsgenius

GENIUS_TOKEN = os.getenv("GENIUS_API_TOKEN")

if GENIUS_TOKEN is None:
    raise ValueError(
        "Genius API token not found. Please set GENIUS_API_TOKEN as an environment variable."
    )

genius = lyricsgenius.Genius(
    GENIUS_TOKEN,
    skip_non_songs=True,
    remove_section_headers=True,
    excluded_terms=["(Remix)", "(Live)"]
)

print("Genius client initialized successfully.")
# Out:
# Genius client initialized successfully.

# %%
def clean_artist(artist):
    return artist.split(",")[0].strip()
def clean_title(title):
    title = re.sub(r"\(.*?\)", "", title)  
    title = re.sub(r"- .*", "", title)     
    return title.strip()
    
pre_streaming_data = pd.read_csv("data/02-processed/pre_streaming_top10_annual")
post_streaming_data = pd.read_csv("data/02-processed/post_streaming_top10_annual")

pre_streaming_data["genius_artist"] = pre_streaming_data["artists"].apply(clean_artist)
pre_streaming_data["genius_title"] = pre_streaming_data["song"].apply(clean_title)

post_streaming_data["genius_artist"] = post_streaming_data["artists"].apply(clean_artist)
post_streaming_data["genius_title"] = post_streaming_data["song"].apply(clean_title)

# %%
pre_streaming_data
# Out:
#      Unnamed: 0  year                                song  era  \
# 0             0  2000                           "Breathe"  pre
# 1             1  2000                            "Smooth"  pre
# 2             2  2000                       "Maria Maria"  pre
# 3             3  2000                      "I Wanna Know"  pre
# 4             4  2000               "Everything You Want"  pre
# ..          ...   ...                                 ...  ...
# 125         125  2012                     "Glad You Came"  pre
# 126         126  2012  "Stronger (What Doesn't Kill You)"  pre
# 127         127  2012                     "We Found Love"  pre
# 128         128  2012                         "Starships"  pre
# 129         129  2012          "What Makes You Beautiful"  pre
#
#                      artists     genius_artist                genius_title
# 0                 faith hill        faith hill                   "Breathe"
# ...

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
import pandas as pd

def fetch_lyrics(row, era):
    title = row["genius_title"]
    artist = row["genius_artist"]

    try:
        song = genius.search_song(title, artist, get_full_info=False)

        return {
            "title": row["genius_title"],
            "artist": row["artists"],
            "lyrics": song.lyrics if song else None,
            "era": era,
            "year": row["year"]  # 👈 ADD THIS
        }

    except Exception as e:
        print(f"Error with {title}: {e}")
        return {
            "title": row["genius_title"],
            "artist": row["artists"],
            "lyrics": None,
            "era": era,
            "year": row["year"]  # 👈 ADD HERE TOO
        }


lyrics_rows = []

# combine datasets so we only parallelize once
tasks = []

for _, row in pre_streaming_data.iterrows():
    tasks.append((row, "pre"))

for _, row in post_streaming_data.iterrows():
    tasks.append((row, "post"))

# run parallel requests
with ThreadPoolExecutor(max_workers=10) as executor:
    futures = [executor.submit(fetch_lyrics, row, era) for row, era in tasks]

    for future in as_completed(futures):
        lyrics_rows.append(future.result())

# create dataframe
final_df = pd.DataFrame(lyrics_rows)

# %%
final_df
# Out:
#                      title                     artist  \
# 0                 "Amazed"                   lonestar
# 1    "Everything You Want"           vertical horizon
# 2                 "Smooth"         santana,rob thomas
# 3            "Maria Maria"    santana,the product g,b
# 4           "I Wanna Know"                        joe
# ..                     ...                        ...
# 255            "I'm Good "    david guetta,bebe rexha
# 256      "I Had Some Help"  post malone,morgan wallen
# 257                 "APT."            rosé,bruno mars
# 258             "Ordinary"                alex warren
# 259       "Pink Pony Club"              chappell roan
#
#                                                 lyrics   era  year
# 0    Every time our eyes meet\nThis feeling inside ...   pre  2000
# 1    Somewhere there's speaking, it's already comin...   pre  2000
# 2    Man, it's a hot one\nLike seven inches from th...   pre  2000
# ...

# %%
final_df.to_csv("data/02-processed/genius-lyrics-dataset")

# %% [markdown]
# The following section runs the Genius Lyrics through the AI Sentiment Analysis tool created by Nyckel.

# %%
genius_df = pd.read_csv("data/02-processed/genius-lyrics-dataset")
genius_df.dropna()
genius_df = genius_df.loc[:, ~genius_df.columns.str.contains('^Unnamed')]

# %%
import pandas as pd
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')

sia = SentimentIntensityAnalyzer()

def clean_lyrics(text):
    if pd.isna(text):
        return ""
    return text.replace("\n", " ").strip()

genius_df['lyrics_clean'] = genius_df['lyrics'].apply(clean_lyrics)

genius_df['sent_scores'] = genius_df['lyrics_clean'].apply(sia.polarity_scores)

genius_df['compound'] = genius_df['sent_scores'].apply(lambda x: x['compound'])

def label_sentiment(score):
    if score >= 0.05:
        return "Positive"
    elif score <= -0.05:
        return "Negative"
    else:
        return "Neutral"

genius_df['sentiment'] = genius_df['compound'].apply(label_sentiment)

# %%
genius_df
# Out:
#                      title                     artist  \
# 0                 "Amazed"                   lonestar
# 1    "Everything You Want"           vertical horizon
# 2                 "Smooth"         santana,rob thomas
# 3            "Maria Maria"    santana,the product g,b
# 4           "I Wanna Know"                        joe
# ..                     ...                        ...
# 255            "I'm Good "    david guetta,bebe rexha
# 256      "I Had Some Help"  post malone,morgan wallen
# 257                 "APT."            rosé,bruno mars
# 258             "Ordinary"                alex warren
# 259       "Pink Pony Club"              chappell roan
#
#                                                 lyrics   era  year  \
# 0    Every time our eyes meet\nThis feeling inside ...   pre  2000
# 1    Somewhere there's speaking, it's already comin...   pre  2000
# 2    Man, it's a hot one\nLike seven inches from th...   pre  2000
# ...

# %%
genius_df = genius_df.loc[:, ~genius_df.columns.str.contains('^Unnamed')]
genius_df.to_csv("data/02-processed/lyrics_sentiment_analysis")

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# To answer our research question and determine if mainstream music has become more homogenized in the streaming era (2013-2026) compared to the pre-streaming era(2000-2012), we performed analysis on the extracted music features both between eras in order to conclude if an observable difference exists at all and within the eras themselves for a homogeneity metric. In this section, we will be comparing musical traits between mainstream songs from both eras, defining popularity via the samples from the Billboard Top 50 charts. We observe the difference in standard deviations, variance, and data density between quantitative musical features like danceability, energy, loudness, speechiness, acousticness, valence, tempo, and song sentiment to determine whether variability from mainstream music has changed across varying technological time periods.

# %% [markdown]
# ### Variability of Individual Continuous and Categorical Features Between Pre- and Post-streaming Eras

# %% [markdown]
# To evaluate whether the variability of mainstream music has changed between the pre-streaming era (2000–2012) and the streaming era (2013–2026), we compare the distributions of several features, including acousticness, danceability, energy, loudness, speechiness, tempo, valence, and duration. For categorical variables, we analyzed key, explicit content, and musical mode.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import chi2_contingency
from scipy.spatial.distance import euclidean

# %%
merged_df.head()
# Out:
#       Unnamed: 0  year_billboard                song   era  \
# 604          125            2012     "Glad You Came"   pre
# 537          109            2010  "Break Your Heart"   pre
# 533          108            2010          "Dynamite"   pre
# 1045         203            2020   "Don't Start Now"  post
# 1047         204            2020          "Rockstar"  post
#
#      artist_clean_billboard        song_clean                      id  \
# 604              the wanted     glad you came  0dw7G0QDuW7UwyL0boHKMU
# 537      taio cruz,ludacris  break your heart  1CdqVF1ywD0ZO1zXtB9yWa
# 533               taio cruz          dynamite  1DqdF42leyFIzqNDv9CjId
# 1045               dua lipa    dont start now  3PfIrDoz19wz7qK7tYeu62
# 1047     dababy,roddy ricch          rockstar  7ytR5pFWmSjzHJIeQkgog4
#
#                               name                    artists release_date  \
# 604                  Glad You Came             ['The Wanted']   2012-01-01
# ...

# %%
continuous_features = ["acousticness","danceability","energy","loudness","speechiness","tempo","valence","duration_min"]
categorical_features = ["key", "explicit", "mode"]

# %%
#Box plots for continuous features
n = len(continuous_features)

fig, axes = plt.subplots(3, 3, figsize=(14,12))
axes = axes.flatten()

for i, feature in enumerate(continuous_features):
    
    sns.boxplot(
        data=merged_df,
        x="era",
        y=feature,
        ax=axes[i]
    )
    
    axes[i].set_title(feature)

plt.tight_layout()
plt.show()

# %% [markdown]
# The above boxplots suggest that several of the features do not show a significant difference between the pre- and post- streaming eras. At this stage, we predict that with the exception of duration, energy, and loudness, several of the other features are unlikely to prove a statistically significant difference. We continue with Cohen's analysis of effect size to support or disprove this hypothesis.

# %%
#Cohen's d to measure effect size
def cohens_d(x, y):
    
    nx = len(x)
    ny = len(y)
    
    pooled_std = np.sqrt(((nx-1)*np.var(x) + (ny-1)*np.var(y)) / (nx+ny-2))
    
    return (np.mean(x) - np.mean(y)) / pooled_std

# %%
#Cohen's d and T-test for continuous features between pre- and post-streaming eras
results = []

for feature in continuous_features:
    
    pre = pre_streaming_features[feature].dropna()
    post = post_streaming_features[feature].dropna()
    
    t, p = stats.ttest_ind(pre, post, equal_var=False)
    
    d = cohens_d(pre, post)
    
    results.append({
        "feature": feature,
        "t_stat": t,
        "p_value": p,
        "cohens_d": d
    })

import pandas as pd
results_df = pd.DataFrame(results)

results_df
# Out:
#         feature    t_stat       p_value  cohens_d
# 0  acousticness -1.897613  5.939038e-02 -0.264435
# 1  danceability  0.196314  8.445485e-01  0.026158
# 2        energy  2.848366  4.852824e-03  0.387004
# 3      loudness  2.347513  1.994461e-02  0.323363
# 4   speechiness -1.583169  1.149734e-01 -0.215490
# 5         tempo -0.400165  6.894618e-01 -0.054387
# 6       valence  0.456139  6.487781e-01  0.061816
# 7  duration_min  5.058810  9.990415e-07  0.696197

# %% [markdown]
# Energy increased significantly in the streaming era (t = 2.85, p = 0.0049, Cohen’s d = 0.387), indicating that songs in the streaming era tend towards having higher intensity. Similarly, loudness increased significantly (t = 2.35, p = 0.0199, Cohen’s d = 0.323), indicating that modern popular songs are produced with louder levels. These results are consistent with the boxplots, which show an upward shift in the distributions of both energy and loudness after 2013, or rather, after the pre-streaming era. The changes in loudness and energy can be attributed to the evolution in music production technology, particularly better lossless compression and recording technology, which are able to preserve more of the essence of the original recorded music.
#
# Song duration also changed substantially between eras. Duration decreased significantly in the streaming era with t = 5.06, p < 0.000001, and Cohen’s d = 0.696, representing the largest observed effect size among the tested variables. This large effect suggests a meaningful structural change in song length, likely reflecting the incentive in streaming platforms like Spotify, where shorter songs can lead to more plays and therefore, more revenue for the artist.
#
# In contrast, several other features don't show much evidence of change. Danceability (t = 0.196, p = 0.845, d = 0.026), tempo (t = −0.400, p = 0.689, d = −0.054), valence (t = 0.456, p = 0.649, d = 0.062), and speechiness (t = −1.583, p = 0.115, d = −0.215) exhibit highly overlapping distributions between eras. Acousticness shows a minor difference (t = −1.90, p = 0.059), but the effect size remains relatively small (d = −0.264). These findings concur with our previous prediction based on the boxplot visualizations.

# %% [markdown]
# We now observe aggregate differences between categorical features across the eras of interest.

# %%
#Countplots for categorical features between pre- and post-streaming eras
fig, axes = plt.subplots(1,3, figsize=(15,5))

for i, feature in enumerate(categorical_features):
    
    sns.countplot(
        data=merged_df,
        x=feature,
        hue="era",
        ax=axes[i]
    )
    
    axes[i].set_title(feature)

plt.tight_layout()
plt.show()

# %% [markdown]
# The above visualizations suggest a potentially signifigant difference in explicitness and in certain keys. In order to confirm, we perform a Chi squared test.

# %%
#Chi squared test to measure statistical significance of differences between categorical features
cat_results = []

for feature in categorical_features:
    
    table = pd.crosstab(merged_df[feature], merged_df["era"])
    
    chi2, p, dof, expected = chi2_contingency(table)
    
    cat_results.append({
        "feature": feature,
        "chi2": chi2,
        "p_value": p
    })

cat_results_df = pd.DataFrame(cat_results)
cat_results_df
# Out:
#     feature       chi2   p_value
# 0       key  13.034504  0.291076
# 1  explicit   9.002008  0.002697
# 2      mode   0.012703  0.910261

# %%
def cramers_v(table):
    
    chi2 = chi2_contingency(table)[0]
    n = table.sum().sum()
    
    r, k = table.shape
    
    return np.sqrt(chi2 / (n * (min(r-1, k-1))))

# %%
#Using Cramér's V to measure the effect size of the difference between categorical features
for feature in categorical_features:
    
    table = pd.crosstab(merged_df[feature], merged_df["era"])
    
    v = cramers_v(table)
    
    print(feature, v)
# Out:
# key 0.23910014034395585
# explicit 0.1987020120271613
# mode 0.007464367521234388

# %% [markdown]
# The proportion of songs marked as explicit increased significantly in the streaming era, according to the Chi-squared test(χ² = 9.00, p = 0.0027), suggesting a greater prevalence of explicit lyrical content in modern popular music, which can be explained by a shift in cultural norms and the societal acceptance of explicit language and explicit themes. However, the distributions of musical key (χ² = 13.03, p = 0.291) and mode (χ² = 0.013, p = 0.910) show no statistically significant differences across eras, indicating that tonal structure has remained stable, likely representing unchanging industry standards and the stability of mainstream tastes.
#
# However, the relatively low Cramér's V values indicate that the strength of association between era and our categorical data values is very little, as generally values above 0.25 are considered significant correlation. Even for explicitness, the Cramér's V value was less than this specified threshold, indicating a relatively weak relationship between explicitness and era, even though it measured to be statistically signifigant by the Chi-squared test.

# %% [markdown]
# ### Computing Overall Feature Diversity for Pre-streaming VS. Post-streaming Era (Continuous Features Only)
#
# We now deep dive into the continuous features, examining their homogeneity within each era of interest to determine weather or not there is a statistically significant difference between the diversity of both eras.

# %%
diversity_features = [
    "acousticness",
    "danceability",
    "energy",
    "loudness",
    "speechiness",
    "tempo",
    "valence",
    "duration_min"
]

# %%
merged_df["diversity_score"] = merged_df[diversity_features].abs().mean(axis=1)
pre_div = merged_df[merged_df["era"] == 'pre']
post_div = merged_df[merged_df["era"] == 'post']

# %%
#Boxplot of Musical Diversity by Era
plt.figure(figsize=(6,5))

sns.boxplot(
    data=merged_df,
    x="era",
    y="diversity_score"
)

plt.title("Musical Diversity Score by Era")
plt.show()

# %% [markdown]
# In order to measure the quantity of musical characteristics, we used the standardized Spotify audio features for each song in order to compute a musical diversity score between each song. We did so by comparing the differences in standard deviations across all categories. Using the song traits: acousticness, danceability, energy, instrumentalness, speechiness, tempo, valence, loudness, and duration, we measure each song from the Billboard charts from before and after the streaming era, and were able to calculate how diverse, if at all, songs were from each other. We then compared the diversity score between songs from the pre-streaming era and from the streaming era. Comparing both periods, we see that the mean diversity score for the pre-streaming era is (0.7098) and the streaming era is (0.7085), which shows that the mean scores for the two eras are almost the same.

# %%
#Density Plot of Distribution of Musical Diversity Across Eras
plt.figure(figsize=(7,5))

sns.kdeplot(pre_div["diversity_score"], label="Pre-streaming", fill=True)
sns.kdeplot(post_div["diversity_score"], label="Post-streaming", fill=True)

plt.title("Distribution of Musical Diversity Scores")
plt.legend()
plt.show()

# %% [markdown]
# In the above figure, we analyzed density to confirm our comparisons of the diversity across both eras. As both the pre- and post- streaming curves were almost identical in distributions, we predicted seeing very little difference in the homogeneity across both eras.

# %%
#Testing normality of results
stats.shapiro(pre_div["diversity_score"])
stats.shapiro(post_div["diversity_score"])
# Out:
# ShapiroResult(statistic=0.9820066656776002, pvalue=0.19516946116979011)

# %%
#p > 0.05 - results are normal. Using the Welch t-test for normal data:
stats.ttest_ind(
    pre_div["diversity_score"],
    post_div["diversity_score"],
    equal_var=False
)
# Out:
# TtestResult(statistic=0.06831224721972268, pvalue=0.9456086378028412, df=190.7272032337035)

# %%
#Effect size of diversity scores
def cohens_d(x,y):
    pooled_sd = np.sqrt((x.var() + y.var()) / 2)
    return (x.mean() - y.mean()) / pooled_sd

cohens_d(pre_div["diversity_score"], post_div["diversity_score"])
# Out:
# 0.009228117533153652

# %% [markdown]
# We conduct several more tests to confirm our hypothesis about a lack of significant difference between our two eras of interest. A Shapiro–Wilk test (p = 0.195) indicated little to no significant deviation from normality. We therefore conducted a two-sample t-test, which yielded a p-value of 0.946, providing no evidence of a significant difference in mean feature variability between the two eras.
#
# To further quantify the magnitude of this difference, we compute Cohen’s d, obtaining a value of around 0.07, which corresponds to a negligible effect size. This suggests that any observed differences in homogeneity are not only statistically insignificant but also practically minimal.
#
# Taken together, these results indicate that the overall level of musical homogeneity across a wide range of audio characteristics has remained stable despite the transition to the streaming era.

# %%
merged_df.groupby("era")["diversity_score"].describe()
# Out:
#       count      mean       std       min       25%       50%       75%  \
# era
# post   99.0  0.708535  0.152065  0.289603  0.627793  0.711118  0.799279
# pre   129.0  0.709833  0.128287  0.360819  0.630311  0.710248  0.783594
#
#            max
# era
# post  1.260902
# pre   1.062104

# %%
merged_df["date"] = pd.to_datetime(merged_df["year_billboard"], format="%Y")
centroid = merged_df[diversity_features].mean()

merged_df["diversity_score"] = merged_df[diversity_features].apply(
    lambda row: euclidean(row, centroid),
    axis=1
)

diversity_year = merged_df.groupby("year_billboard")["diversity_score"].mean().reset_index()

plt.figure(figsize=(10,6))

sns.lineplot(
    data=diversity_year,
    x="year_billboard",
    y="diversity_score",
    marker="o"
)

plt.axvline(2013, color="red", linestyle="--", label="Streaming Era Begins")

plt.title("Musical Diversity of Billboard Top Songs Over Time")
plt.xlabel("Year")
plt.ylabel("Average Diversity Score")

plt.legend()
plt.show()

# %% [markdown]
# This final figure in our exploration of continuous features shows a graph of musical diversity over time. Fluctuations in diversity from year to year make the overal diversity scores across eras relatively similar. However, it is worth observing how diverity can peak and trough depending on the year. An analysis of smaller time frames likely would have shown much more difference in diversity guided by yearly trends and popular sentiments, but these difference stabilize when examined as part of a bigger picture.

# %% [markdown]
# ### Analysis of Lyric Sentiment Over Time And Across Distribution Eras
#
# We extend our analysis of music homogeneity by shifting focus from audio features to lyrical content. Using a dataset of Billboard Top 50 songs, augmented with lyrics retrieved via the Genius API, we apply VADER, a sentiment analysis tool from the Natural Language Toolkit (NLTK), to quantify lyrical sentiment. In this section, we examine whether the emotional tone of popular music has evolved alongside changes in music distribution. Additionally, we assess shifts in homogeneity by analyzing the variance and distribution of compound sentiment scores over time.

# %%
lyric_sentiments = pd.read_csv("data/02-processed/lyrics_sentiment_analysis")
genius_df = genius_df.loc[:, ~genius_df.columns.str.contains('^Unnamed')]
lyric_sentiments
# Out:
#      Unnamed: 0                  title                     artist  \
# 0             0               "Amazed"                   lonestar
# 1             1  "Everything You Want"           vertical horizon
# 2             2               "Smooth"         santana,rob thomas
# 3             3          "Maria Maria"    santana,the product g,b
# 4             4         "I Wanna Know"                        joe
# ..          ...                    ...                        ...
# 255         255            "I'm Good "    david guetta,bebe rexha
# 256         256      "I Had Some Help"  post malone,morgan wallen
# 257         257                 "APT."            rosé,bruno mars
# 258         258             "Ordinary"                alex warren
# 259         259       "Pink Pony Club"              chappell roan
#
#                                                 lyrics   era  year  \
# 0    Every time our eyes meet\nThis feeling inside ...   pre  2000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=genius_df, x='sentiment', hue='era')
plt.title("Sentiment Distribution: Pre vs Post Streaming")
plt.show()

# %% [markdown]
# Visually, the difference between raw distribution of sentiment values seems to be negligible. The little variance shown is likely not enough to concurr a signifigant difference between the two eras, particularly in the face of confounding variables like VADER's accuracy with song lyrics and in the slight difference between sample size for the pre and post streaming groups.

# %%
yearly_era = genius_df.groupby(['year', 'era'])['compound'].mean().reset_index()

sns.lineplot(data=yearly_era, x='year', y='compound', hue='era')
plt.title("Sentiment Trends Over Time by Era")
plt.show()

# %% [markdown]
# The above graph tracks changes trends in mean sentiment over the years of our sample. Above 0.5 is a positive rating and below 0.5 is a negative rating with the middle values being closest to neutral. In this graph, there seems to be generally be more negative sentiments in song lyrics in the post-streaming years, which reflects the differences in the aggregate numbers of positive and negative sentiments in the dataset pictured in the boxplot above.

# %%
from scipy.stats import ttest_ind

pre = genius_df[genius_df['era'] == 'pre']['compound']
post = genius_df[genius_df['era'] == 'post']['compound']

ttest_ind(pre, post, equal_var=False)
# Out:
# TtestResult(statistic=-1.452547646688574, pvalue=0.14757963824898304, df=254.81637113023808)

# %% [markdown]
# The above Ttest result shows a p-value of over 0.6, which is far above the <=0.05 needed to determine statistical signifigcance. Thus we fail to come to the conlcusion that there is a notable difference between sentiment between songs from the pre and post streaming eras.

# %% [markdown]
# However, this data only shows the similarities and differences between the sentiments of both eras. Though the p-value indicated that there is not a statistically significant differnce between the means of sentiment between both eras, there still might be a difference in overall homogeneity. We measure homogeneity based on the variance of compound sentiment values amongst the pre and post streaming eras individually, then compare.

# %%
pre_var = genius_df[genius_df['era'] == 'pre']['compound'].var()
post_var = genius_df[genius_df['era'] == 'post']['compound'].var()

print("Pre variance:", pre_var)
print("Post variance:", post_var)
# Out:
# Pre variance: 0.5811850114519966
# Post variance: 0.7274597478598686

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=genius_df, x='era', y='compound')
plt.title("Sentiment Spread by Era")
plt.show()

# %% [markdown]
# As indicated by the above boxplot and similarity in variance values between both eras, there likely is not a difference in homogeneity between the two eras; they seem to emulate the lack of significant difference in mean and aggregate counts of positive and negative sentiments showed in the previous section. We can continue to test the robustness of this conclusion via performing a test on the density of sentiment distributions by era.

# %%
sns.kdeplot(data=genius_df, x='compound', hue='era', fill=True)
plt.title("Sentiment Distribution by Era")
plt.show()

# %% [markdown]
# As shown by the overlap between the two density maps, there does not appear to be much difference between era homogeneity, which supports the conclusion drawn by the previous figure. As a final, conclusive test of this hypothesis, we compare the standard deviations across both eras and perform a Levene test, which aims to test the null hypothesis that the variance between two examined groups is equal.

# %%
pre = genius_df[genius_df['era'] == 'pre']['compound']
post = genius_df[genius_df['era'] == 'post']['compound']

# Standard deviations
pre_std = pre.std()
post_std = post.std()

print("Pre std:", pre_std)
print("Post std:", post_std)
# Out:
# Pre std: 0.7623549117386184
# Post std: 0.8529125089127657

# %% [markdown]
# There is an evidently marginal difference in standard deviations between eras, which further supports a lack in homogeneity differnces.

# %%
from scipy.stats import levene

pre = genius_df[genius_df['era'] == 'pre']['compound']
post = genius_df[genius_df['era'] == 'post']['compound']

levene(pre, post)
# Out:
# LeveneResult(statistic=0.014262155098752803, pvalue=0.9050321759294733)

# %% [markdown]
# Supporting the minimal homogeneity differences shown in the figures, the variance values, and the standard deviations, the Levene test yielded a p-value of 0.62. As this value is well above conventional significance thresholds, we fail to reject the null hypothesis of equal variances. This provides strong evidence that the variability of lyrical sentiment—and thus the degree of homogeneity—has not meaningfully changed between the pre-streaming era of the early 2000s and the modern streaming era.

# %% [markdown]
# At a broader level, this finding challenges our hypothesis that the rise of streaming platforms and algorithmic curation of music profiles has led to greater uniformity in popular music. Despite significant shifts in how music is distributed and consumed, the emotional diversity of top-charting songs appears largely unchanged. This stability may reflect enduring industry dynamics such as consistent listener preferences, the influence of major labels, or the nature of musical trends that continue to shape the emotional landscape of popular music regardless of technological change. However, it must be considered that the VADER test used to classify sentiment only groups lyrics into "positive" and "negative" categories, which does not represent the entire spectrum of emotions often expressed in music lyrics. The VADER tool was also initially designed to analyze the sentiment of social media posts, which makes it much worse at analyzing metaphorical or symbolic elements that are extremely prevalent in song lyrics. It also does not correctly compute sentiment for non-English lyrics. Thus, although this test concluded that, based on our data, there is not a statistically significant difference in emotional homogeneity across eras, it may be possible that a different or more specific sentiment analysis would reflect different results.
#
# More generally, our analysis and results across musical and lyrical features both highlight that structural changes in the distribution of music do not necessarily translate to changes in creativity and diversity at the aggregate level. While streaming has transformed access and exposure, it may not have fundamentally altered the range of expression that resonates with mainstream audiences. Instead, the features that define mainstream appeal appear to persist over time, pointing to enduring patterns in listener preferences and industry production norms. The features that did prove statistically significant in difference across the eras, such as energy, loudness, and explicitness, had negligible correlation to the era variable. Even though such factors did change, likely due to evolving technology and societal norms, it was not to an impactful enough degree to claim that there is a measurable difference in musical diversity from before and after streaming became popularized. Thus, we conclude that our hypothesis about post-streaming songs being less diverse cannot be sufficiently supported, as a majority of our analysis and testing proved that the homogeneity between the two eras is negligibly different in terms of the variables we examined.

# %% [markdown]
# ## Ethics

# %% [markdown]
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [ ] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
# > Because we are only looking at the top 50 Billboard Hot 100 songs, selection bias may occur due to factors such as audience preference, popularity, and marketing power. Selection bias will lean towards successful artists and popularized genres that hold these factors, making the scope of songs analyzed less diverse because we will be excluding various genres that are less popular and more niche.
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
# > The data that will be analyzed in this project comes from publicly available Billboard Hot 100 chart information. The analysis focuses only on the top three songs per period and does not collect or use any personal or private data. As a result, there is no exposure of personally identifiable information.
#  - [ ] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [ ] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  - [ ] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [ ] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
# > Since we will be analyzing the Billboard Hot 100 chart and more specifically the top 50 songs of the chart, it is likely that the top 50 songs will have alike genres, audiences, and artists. This results in the analysis overlooking qualitative factors that play a role in music like culture, sociopolitical influences, and artistic expression that quantitative factors fail to capture. This fails to include the analysis of songs and genres who do not qualify as mainstream charting music.
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
# > The Billboard Hot 100 chart is composed of songs that are most popular in the U.S. that  lead to geographic and cultural biases in the dataset. This overrepresentation of U.S. trends in music affects the conclusion being made about musical homogenization because it excludes global trends, artists, and listening patterns in music that is not part of mainstream U.S. music
#  - [ ] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
# > The analysis conducted to form a response to the research question is based solely on songs and music trends that are publicly shared and are not focused on private individuals.
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
# > The analysis includes data sources that are traceable and can be accessed by anyone who later on wishes to analyze it too. The well documented data also includes preprocessing steps and analytical methods that are used to reach a conclusion. Together this project can be reanalyzed by later on researchers, allowing them to either replicate results or identify potential errors.
#
# ### D. Modeling
#  - [ ] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  - [ ] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
# > The variables that will be used to measure similarities over the years are mainly audio based such as tempo, danceability, and instrumentals. We do not include other factors such as emotion and cultural significance which can also affect our conclusion.
#  - [ ] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
# > As previously stated, the data sets are limited to U.S. music trends, mainstream songs, quantitative features and exclude niche genres, cultural and emotional significance, and qualitative features.
#
# ### E. Deployment
#  - [ ] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
# > Since the project only focuses on the composition of songs and analyzes factors that observe how songs are homogenized throughout the years,no users will be directly harmed with the results of the model, making redress in inapplicable.
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
# > Looking to see if songs have become more homogenized over the years, there is the possibility that people may use the results of the model to criticize mainstream songs and popular genres of music. We acknowledge some may use the results of the model to target artists or nowadays popular music and will work carefully and respectfully to form a carefully presented analysis and conclusion, focusing on limitations and avoiding judgement to artists and their music.

# %% [markdown]
# ## Discusison and Conclusion
#
# The purpose of this project was to find if the emerging popularity of streaming services had influenced or caused the homogenization of mainstream music. To determine if songs had become more homogenized with the rise of streaming devices, we used Billboard top 50 songs from the pre-streaming era (2000-2012) and compared them with songs from the streaming era (2013 - 2026). To compare and measure these songs from both eras, we used song characteristics such as energy, tempo, loudness, acousticness, and lyrical sentiments. The results we found were that multiple musical characteristics of songs have evolved over the eras, like energy, loudness, and lyrical sentiments. Analyzing the findings, we can find that songs in the streaming era are significantly louder, show higher energy levels, and tend to be more vulgar/explicit lyric wise. However, though there have been some shifts in these characteristics over the years, we find that these changes are not statistically significant or show a great difference in overall variability in popular music between the two eras. The results display that the music diversity scores between the pre-streaming era and the streaming era had no significant difference, but rather were almost identical (0.7098 vs 0.7085), which shows us that mainstream music has not become more homogeneous over the years.
#
# Looking beyond the comparison of songs from these two eras, we find that there has been a massive increase in streaming platforms, and these streaming platforms have introduced the usage of algorithm-driven systems to advertise and recommend songs. Naturally, the idea that the songs streaming platforms push out to the audience causes them to gain more exposure, hence gain more popularity, is straightforward. Despite this, though, these findings from this project inform us that while streaming platforms and algorithm-driven systems influence the popularity of songs, they do not change or influence the diversity between songs and their musical characteristics. Rather than being the cause of how diverse songs are, streaming platforms have caused trends in musical characteristics. These trends we can see are high loudness levels and shorter song durations, which influence our cognition. With these fast-paced songs, the music industry gains more revenue, we quickly forget about these songs, and then another song is being pushed out for our consumption. However, as stated before, though trends influence how songs are generated, the overall diversity scores of music between the pre-streaming era and the streaming era are constant.
#
# Though these observations answered our question whether songs had become more homogenized with the rise of streaming devices, there are some limitations to consider when looking at our findings. Since we used the top songs from Billboard charts to compare the songs and see if they displayed homogenization, the findings are biased towards it. The songs usually seen on Billboard charts mostly come from the United States and exclude other popular songs from other regions of the world. The findings only include evolved trends and diversity from popular songs in the U.S., so it is important to consider that these findings are limited and exclude global trends and popularities. Another limitation observed in our datasets to consider is that the songs we are analyzing and comparing are only the top-charting songs from the Billboard charts. This means that we exclude more niche and unique music and artists from our datasets and only observe changes in mainstream music. If others were to redo or conduct this project in the future, they could be able to get more accurate results by including global charts and broader song genres in their datasets to analyze and compare. Including more song genres and global song trends to observe and compare from the pre-streaming era versus the streaming era can influence the results and display whether streaming platforms have an effect on whether songs have become more homogenized with their emergence. Beyond these limitations, though, our datasets have shown that songs have evolved in music characterization over the years, with the influence of trends and streaming platforms, but not enough to say that songs have become more homogenized.
