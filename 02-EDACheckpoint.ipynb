# %% [markdown]
# ## Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
#  Scoring: Out of 10 points
#
# - Each Developing  => -2 pts
# - Each Unsatisfactory/Missing => -4 pts
#   - until the score is 0
#
# If students address the detailed feedback in a future checkpoint they will earn these points back
#
#
#
#
#
#
# |                                  | **Unsatisfactory**                                                                                                                                                                                                                                                                                                                        | **Developing**                                                                                                                                                                                                       | **Proficient**                                                                                                                                                                                            | **Excellent**                                                                                                                                                                            |
# |----------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **EDA relevance**                | EDA is mostly neither relevant to the question nor helpful in figuring out how to address the question. Or the EDA does address the question, but many obviously relevant variables / analyses / figures were not included. | EDA is partly irrelevant/unhelpful. EDA missed one or two obvioulsy relevant analysis (distributions of single variables or relationships between variables) | EDA includes the obviously relevant / helpful variables in addressing the question.                                                              | Thorough EDA fully explored the dataset                                                                                                                 |
# | **EDA analysis and description** | Many of the analyses are poor choices (e.g., using means instead of medians for obviously skewed data), or are poorly described in the text, or do not aid understanding the data                                                                                                                                                     | Some of the analyses are poor choices, or are poorly described in the text, or do not aid understanding the data                                                                                                 | All analyses are correct choices. Only one or two have minor issues in the text descriptions supporting them. Mostly they fit well with other elements of the EDA and support understanding the data  | All analyses are correct choices with clear text descriptions supporting them. The figures fit well with the other elements of the EDA, producing a clear understanding of the data. |
# | **EDA figures**                  | Many of the figures are poor plot choices (e.g., using a bar plot to represent a time series where it would be better to use a line plot) or have poor aesthetics (including colormap, data point shape/color, axis labels, titles, annotations, text legibility) or do not aid understanding the data                                | Some of the figures are poor plot choices or have poor aesthetics. Some figures do not aid understanding the data                                                                                                | All figures are correct plot choices. Only one or two have minor questionable aesthetic choices. The figures mostly fit well with the other elements of the EDA and support understanding the data    | All figures are correct plot choices with beautiful aesthetics. The figures fit well with the other elements of the EDA, producing a clear understanding of the data.                |

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# ## Authors
#
# Instructions: REPLACE the contents of this cell with your team list and their contributions. Note that this will change over the course of the checkpoints
#
# This is a modified [CRediT taxonomy of contributions](https://credit.niso.org). For each group member please list how they contributed to this project using these terms:
# > Analysis, Background research, Conceptualization, Data curation, Experimental investigation, Methodology, Project administration, Software, Visualization, Writing – original draft, Writing – review & editing
#
# Example team list and credits:
# - Alice Anderson: Conceptualization, Data curation, Methodology, Writing - original draft
# - Bob Barker:  Analysis, Software, Visualization
# - Charlie Chang: Project administration, Software, Writing - review & editing
# - Dani Delgado: Analysis, Background research, Visualization, Writing - original draft

# %% [markdown]
# # Research Question

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback

# %% [markdown]
# # Hypothesis

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your data checkpoint feedback

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- Run only once after cloning!!! 
#
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
     { 'url': 'https://raw.githubusercontent.com/FCPercival/spotify-data-sorted/refs/heads/master/data.csv', 'filename':'music-data.csv'},
     
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')

# %% [markdown]
# ### Dataset #1:
# Instructions: REPLACE the contents of this cell and the one below with your work, including any updates to recover points lost in your data checkpoint feedback

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ### Dataset #2
# as above, add any more copies of this that you need to given how many datasets you have

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Instructions: replace the words in this subsection with whatever words you need to setup and preview the EDA you're going to do.
#
# Please explicitly load the fully wrangled data you will use from `data/02-processed`.  This is a good idea rather than forcing people to re-run the data getting / wrangling cells above.  Sometimes it takes a long time to get / wrangle data compared to reloading the fixed up dataset.
#
# Carry out whatever EDA you need to for your project in the code cells below.  Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.
#
# Please note that you should consider the use of python modules in your work.  Any code which gets called repeatedly should be modularized. So if you run the same pre-processing, analysis or visualiazation on different subsets of the data, then you should turn that into a function or class.  Put that function or class in a .py file that lives in `modules/`.  Import the module you made and use it to get your work done.  For reference see `get_raw()` which is inside `modules/get_data.py`.

# %% [markdown]
# #### Section 1 of EDA - Musical Feature Variability Across Pre-streaming and Post-streaming Eras
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
features_00_13['era'] = 'Pre-streaming'
features_14_26['era'] = 'Post-streaming'

features_eda = pd.concat([features_00_13, features_14_26], ignore_index=True)
features_eda
# Out:
#                           id                  name                   artists  \
# 0     41bIQPBE1lFN0mmw6Lmssz          21 questions  ['50 cent', 'nate dogg']
# 1     56fXFvwIGDLvWFhuZtWhrO          21 questions  ['50 cent', 'nate dogg']
# 2     6pymOcrCnMuCWdgGVTvUgP                     3        ['britney spears']
# 3     3g6SuyjGaGyAXmjvdNI1IU             4 minutes                 ['avant']
# 4     4kvdX9zzsix7jYHsRVkVUH    a moment like this        ['kelly clarkson']
# ...                      ...                   ...                       ...
# 1716  2Fxmhks0bxGSBdJ92vM42m               bad guy         ['billie eilish']
# 1717  69jGxyfw3lzGGYf78jdkpF               flowers               ['nujabes']
# 1718  6E37j4b44JGpdk297urpKM             like that            ['bea miller']
# 1719  2qT1uLXPVPzGgFOx4jtEuo  no tears left to cry         ['ariana grande']
# 1720  6gyYI35SD576xiwstBIX7Y                 sorry                ['chief.']
#
#      release_date_x  year_x  acousticness  danceability    energy  \
# 0            2/6/03    2003     -0.372296      0.215880  1.190803
# 1            2/6/03    2003     -0.372296      0.215880  1.190803
# 2           11/9/09    2009     -1.189550      0.905952  0.824297
# 3            1/1/06    2006     -1.059448      1.653055  0.416653
# 4           4/15/03    2003     -0.876774     -0.708018  0.311937
# ...             ...     ...           ...           ...       ...
# 1716        3/29/19    2019     -0.438675      0.928764 -0.237822
# 1717       11/11/05    2005      0.936690      0.746266  0.461531
# 1718        2/23/18    2018     -0.815705      0.198771 -0.177984
# 1719        8/17/18    2018     -1.203357      0.917358  0.839256
# 1720        12/8/17    2017      0.687107      0.056194 -0.697824
#
#       instrumentalness  loudness  ...  Rank  Last Week  Peak Position  \
# 0            -0.522343  1.316853  ...     1          2              1
# 1            -0.522343  1.316853  ...     1          2              1
# 2            -0.523517  1.668199  ...     1          1              1
# 3            -0.523517  1.048446  ...     3         68              3
# 4            -0.523517  1.315088  ...     1         52              1
# ...                ...       ...  ...   ...        ...            ...
# 1716         -0.103253  0.071524  ...     3          4              3
# 1717          0.229726  0.988624  ...     1          1              1
# 1718         -0.523517  0.983153  ...     1          1              1
# 1719         -0.523507  1.034682  ...     3          3              1
# 1720          2.363374 -0.264469  ...     2          2              1
#
#       Weeks in Charts  Image URL  release_date_y  year_y month  \
# 0                  11          #      2003-05-28    2003     5
# 1                  11          #      2003-05-28    2003     5
# 2                   -          #      2009-10-21    2009    10
# 3                   2          #      2008-04-09    2008     4
# 4                   3          #      2002-10-02    2002    10
# ...               ...        ...             ...     ...   ...
# 1716                8          #      2019-05-29    2019     5
# 1717                -          #      2023-01-25    2023     1
# 1718                -          #      2024-04-03    2024     4
# 1719                -          #      2018-05-02    2018     5
# 1720                -          #      2015-11-11    2015    11
#
#                            artists_norm_y             era
# 0                       50 cent,nate dogg   Pre-streaming
# 1                       50 cent,nate dogg   Pre-streaming
# 2                          britney spears   Pre-streaming
# 3     justin timberlake,madonna,timbaland   Pre-streaming
# 4                          kelly clarkson   Pre-streaming
# ...                                   ...             ...
# 1716                        billie eilish  Post-streaming
# 1717                          miley cyrus  Post-streaming
# 1718  future| metro boomin,kendrick lamar  Post-streaming
# 1719                        ariana grande  Post-streaming
# 1720                        justin bieber  Post-streaming
#
# [1721 rows x 31 columns]

# %%
features_eda['chart_date'] = pd.to_datetime(features_eda['release_date_y'])
features_eda['year'] = features_eda['chart_date'].dt.year
features_eda['month'] = features_eda['chart_date'].dt.to_period('M')
features_eda = features_eda.drop(columns=['release_date_x','release_date_y','year_x','year_y'])

features_eda
# Out:
#                           id                  name                   artists  \
# 0     41bIQPBE1lFN0mmw6Lmssz          21 questions  ['50 cent', 'nate dogg']
# 1     56fXFvwIGDLvWFhuZtWhrO          21 questions  ['50 cent', 'nate dogg']
# 2     6pymOcrCnMuCWdgGVTvUgP                     3        ['britney spears']
# 3     3g6SuyjGaGyAXmjvdNI1IU             4 minutes                 ['avant']
# 4     4kvdX9zzsix7jYHsRVkVUH    a moment like this        ['kelly clarkson']
# ...                      ...                   ...                       ...
# 1716  2Fxmhks0bxGSBdJ92vM42m               bad guy         ['billie eilish']
# 1717  69jGxyfw3lzGGYf78jdkpF               flowers               ['nujabes']
# 1718  6E37j4b44JGpdk297urpKM             like that            ['bea miller']
# 1719  2qT1uLXPVPzGgFOx4jtEuo  no tears left to cry         ['ariana grande']
# 1720  6gyYI35SD576xiwstBIX7Y                 sorry                ['chief.']
#
#       acousticness  danceability    energy  instrumentalness  loudness  \
# 0        -0.372296      0.215880  1.190803         -0.522343  1.316853
# 1        -0.372296      0.215880  1.190803         -0.522343  1.316853
# 2        -1.189550      0.905952  0.824297         -0.523517  1.668199
# 3        -1.059448      1.653055  0.416653         -0.523517  1.048446
# 4        -0.876774     -0.708018  0.311937         -0.523517  1.315088
# ...            ...           ...       ...               ...       ...
# 1716     -0.438675      0.928764 -0.237822         -0.103253  0.071524
# 1717      0.936690      0.746266  0.461531          0.229726  0.988624
# 1718     -0.815705      0.198771 -0.177984         -0.523517  0.983153
# 1719     -1.203357      0.917358  0.839256         -0.523507  1.034682
# 1720      0.687107      0.056194 -0.697824          2.363374 -0.264469
#
#       speechiness     tempo  ...  Rank  Last Week  Peak Position  \
# 0        1.486896 -0.876619  ...     1          2              1
# 1        1.486896 -0.876619  ...     1          2              1
# 2       -0.323857  0.584572  ...     1          1              1
# 3        0.453133  0.098322  ...     3         68              3
# 4       -0.419897  0.918936  ...     1         52              1
# ...           ...       ...  ...   ...        ...            ...
# 1716     1.873724  0.591667  ...     3          4              3
# 1717    -0.431902 -0.601193  ...     1          1              1
# 1718    -0.121773 -1.799423  ...     1          1              1
# 1719    -0.231152  0.164193  ...     3          3              1
# 1720     0.173016  0.332319  ...     2          2              1
#
#       Weeks in Charts  Image URL    month  \
# 0                  11          #  2003-05
# 1                  11          #  2003-05
# 2                   -          #  2009-10
# 3                   2          #  2008-04
# 4                   3          #  2002-10
# ...               ...        ...      ...
# 1716                8          #  2019-05
# 1717                -          #  2023-01
# 1718                -          #  2024-04
# 1719                -          #  2018-05
# 1720                -          #  2015-11
#
#                            artists_norm_y             era chart_date  year
# 0                       50 cent,nate dogg   Pre-streaming 2003-05-28  2003
# 1                       50 cent,nate dogg   Pre-streaming 2003-05-28  2003
# 2                          britney spears   Pre-streaming 2009-10-21  2009
# 3     justin timberlake,madonna,timbaland   Pre-streaming 2008-04-09  2008
# 4                          kelly clarkson   Pre-streaming 2002-10-02  2002
# ...                                   ...             ...        ...   ...
# 1716                        billie eilish  Post-streaming 2019-05-29  2019
# 1717                          miley cyrus  Post-streaming 2023-01-25  2023
# 1718  future| metro boomin,kendrick lamar  Post-streaming 2024-04-03  2024
# 1719                        ariana grande  Post-streaming 2018-05-02  2018
# 1720                        justin bieber  Post-streaming 2015-11-11  2015
#
# [1721 rows x 29 columns]

# %%
features_eda.groupby('month').size()
# Out:
# month
# 2000-01     9
# 2000-02     5
# 2000-03    26
# 2000-04     2
# 2000-05     2
#            ..
# 2025-05     2
# 2025-06     1
# 2025-07     5
# 2025-09     7
# 2025-10     1
# Freq: M, Length: 259, dtype: int64

# %%
first_chart_per_month = features_eda.groupby('month')['chart_date'].min().reset_index()
monthly_snapshot = features_eda.merge(first_chart_per_month, on=['month','chart_date'])

# %%
monthly_snapshot.groupby('month').size().value_counts()
# Out:
# 1     79
# 2     71
# 3     33
# 4     19
# 5     10
# 6      9
# 7      7
# 9      5
# 10     4
# 8      4
# 20     3
# 12     3
# 15     2
# 11     2
# 28     1
# 14     1
# 13     1
# 16     1
# 32     1
# 19     1
# 24     1
# 36     1
# Name: count, dtype: int64

# %%
complete_weeks = features_eda.groupby('chart_date').filter(lambda x: len(x) == 3)
print(complete_weeks.groupby('chart_date').size().value_counts())
complete_weeks.groupby('era')['chart_date'].nunique()
# Out:
# 3    61
# Name: count, dtype: int64
# era
# Post-streaming    17
# Pre-streaming     44
# Name: chart_date, dtype: int64

# %%
complete_weeks.columns
# Out:
# Index(['id', 'name', 'artists', 'acousticness', 'danceability', 'energy',
#        'instrumentalness', 'loudness', 'speechiness', 'tempo', 'valence',
#        'mode', 'key', 'explicit', 'duration_min', 'artists_norm_x', 'Date',
#        'Song', 'Artist', 'Rank', 'Last Week', 'Peak Position',
#        'Weeks in Charts', 'Image URL', 'month', 'artists_norm_y', 'era',
#        'chart_date', 'year'],
#       dtype='object')

# %% [markdown]
# Computing Weekly Variability

# %%
weekly_explicit = complete_weeks.groupby(['chart_date','era'])['explicit'].mean().reset_index()
complete_weeks.groupby(['chart_date','era'])['key'].nunique()
# Out:
# chart_date  era
# 2000-06-28  Pre-streaming     2
# 2000-09-13  Pre-streaming     3
# 2000-11-08  Pre-streaming     2
# 2001-04-11  Pre-streaming     3
# 2001-07-18  Pre-streaming     3
#                              ..
# 2023-02-08  Post-streaming    3
# 2023-03-08  Post-streaming    2
# 2023-06-28  Post-streaming    3
# 2023-08-16  Post-streaming    2
# 2024-02-14  Post-streaming    3
# Name: key, Length: 61, dtype: int64

# %%
sns.boxplot(data=weekly_explicit, x='era', y='explicit')
plt.title("Weekly Explicitness in Top-3 Songs by Era")
plt.show()

# %%
weekly_key_div = complete_weeks.groupby(['chart_date','era'])['key'].nunique().reset_index()
weekly_key_div.rename(columns={'key':'num_unique_keys'}, inplace=True)

# %%
sns.boxplot(data=weekly_key_div, x='era', y='num_unique_keys')
plt.title("Weekly Key Diversity in Top-3 Songs by Era")
plt.show()

# %%
features = ['acousticness', 'danceability', 'energy', 'loudness', 'tempo', 'valence', 'duration_min']
weekly_var = (
    complete_weeks
    .groupby(['chart_date','era'])[features]
    .std()
    .reset_index()
)

weekly_long = weekly_var.melt(
    id_vars=['chart_date','era'],
    var_name='feature',
    value_name='variability'
)

# %%
plt.figure(figsize=(14,6))
sns.boxplot(data=weekly_long, x='feature', y='variability', hue='era')
plt.xticks(rotation=45)
plt.title("Weekly Top-3 Variability by Feature and Era")
plt.tight_layout()
plt.show()

# %%
pre = weekly_var[weekly_var['era']=='Pre-streaming']
post = weekly_var[weekly_var['era']=='Post-streaming']

# %%
results = []

# Bonferroni correction
alpha = 0.05
corrected_alpha = alpha / len(features)

def cohens_d(x, y):
    pooled_sd = np.sqrt((x.var() + y.var()) / 2)
    return (x.mean() - y.mean()) / pooled_sd

for feature in features:
    # Shapiro-Wilk test for normality
    p_pre = stats.shapiro(pre[feature])[1]
    p_post = stats.shapiro(post[feature])[1]
    
    normal = (p_pre > 0.05) and (p_post > 0.05)
    
    if normal:
        test_name = "Welch t-test"
        stat, p_val = stats.ttest_ind(pre[feature], post[feature], equal_var=False)
    else:
        test_name = "Mann-Whitney U"
        stat, p_val = stats.mannwhitneyu(pre[feature], post[feature])
    
    d = cohens_d(pre[feature], post[feature])
    
    # Mean SD per era
    mean_pre = pre[feature].mean()
    mean_post = post[feature].mean()
    
    results.append({
        "Feature": feature,
        "Pre-streaming mean SD": mean_pre,
        "Post-streaming mean SD": mean_post,
        "Test": test_name,
        "Stat": stat,
        "p-value": p_val,
        "Bonferroni sig.": p_val < corrected_alpha,
        "Cohen's d": d
    })

results_df = pd.DataFrame(results)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
print(results_df)
# Out:
#         Feature  Pre-streaming mean SD  Post-streaming mean SD  \
# 0  acousticness                  0.279                   0.507
# 1  danceability                  0.422                   0.451
# 2        energy                  0.353                   0.626
# 3      loudness                  0.255                   0.523
# 4         tempo                  0.496                   0.484
# 5       valence                  0.415                   0.587
# 6  duration_min                  0.243                   0.397
#
#              Test    Stat  p-value  Bonferroni sig.  Cohen's d
# 0  Mann-Whitney U 215.000    0.011            False     -0.617
# 1  Mann-Whitney U 327.000    0.454            False     -0.073
# 2  Mann-Whitney U 223.000    0.015            False     -0.733
# 3  Mann-Whitney U 193.000    0.004             True     -0.723
# 4  Mann-Whitney U 322.000    0.407            False      0.022
# 5  Mann-Whitney U 236.000    0.027            False     -0.441
# 6  Mann-Whitney U 230.000    0.021            False     -0.435

# %% [markdown]
# #### Section 2 of EDA if you need it  - please give it a better title than this
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ## Ethics

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# Instructions: Replace this with your timeline.  **PLEASE UPDATE your Timeline!** No battle plan survives contact with the enemy, so make sure we understand how your plans have changed.  Also if you have lost points on the previous checkpoint fix them
