# %% [markdown]
# ## Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 10 points
#
# - Each Developing  => -2 pts
# - Each Unsatisfactory/Missing => -4 pts
#   - until the score is
#
# If students address the detailed feedback in a future checkpoint they will earn these points back
#
#
# |                  | Unsatisfactory                                                                                                                                                                                                    | Developing                                                                                                                                                                                              | Proficient                                     | Excellent                                                                                                                              |
# |------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------|
# | Data relevance   | Did not have data relevant to their question. Or the datasets don't work together because there is no way to line them up against each other. If there are multiple datasets, most of them have this trouble | Data was only tangentially relevant to the question or a bad proxy for the question. If there are multiple datasets, some of them may be irrelevant or can't be easily combined.                       | All data sources are relevant to the question. | Multiple data sources for each aspect of the project. It's clear how the data supports the needs of the project.                         |
# | Data description | Dataset or its cleaning procedures are not described. If there are multiple datasets, most have this trouble                                                                                              | Data was not fully described. If there are multiple datasets, some of them are not fully described                                                                                                      | Data was fully described                       | The details of the data descriptions and perhaps some very basic EDA also make it clear how the data supports the needs of the project. |
# | Data wrangling   | Did not obtain data. They did not clean/tidy the data they obtained.  If there are multiple datasets, most have this trouble                                                                                 | Data was partially cleaned or tidied. Perhaps you struggled to verify that the data was clean because they did not present it well. If there are multiple datasets, some have this trouble | The data is cleaned and tidied.                | The data is spotless and they used tools to visualize the data cleanliness and you were convinced at first glance                      |

# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# ## Authors
#
# Instructions: REPLACE the contents of this cell with your team list and their contributions. Note that this will change over the course of the checkpoints
#
# This is a modified [CRediT taxonomy of contributions](https://credit.niso.org). For each group member please list how they contributed to this project using these terms:
# > Analysis, Background research, Conceptualization, Data curation, Experimental investigation, Methodology, Project administration, Software, Visualization, Writing – original draft, Writing – review & editing
#
# Example team list and credits:
# - Alice Anderson: Conceptualization, Data curation, Methodology, Writing - original draft
# - Bob Barker:  Analysis, Software, Visualization
# - Charlie Chang: Project administration, Software, Writing - review & editing
# - Dani Delgado: Analysis, Background research, Visualization, Writing - original draft

# %% [markdown]
# ## Research Question

# %% [markdown]
# To what extent has the variability in song duration and genre diversity among the monthly top three Billboard Hot 100 songs decreased in the streaming era (2013-2026) relative to the pre-streaming era (2000-2012)?
#
# (We chose this time epoch because 2013 was the beginning of the streaming-dominant era, as it generally marks the first year in which streaming became the primary mode of music consumption in the United States. To allow for a balanced comparison, we chose to analyze an equal span of time before (2000-2012) and after (2013-2026) this shift.)

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# As digitalization has rapidly advanced, no stone has been left unturned. The way we listen to music has been one of the biggest changes; progressing from physical cassettes, records, and CDs to singular devices that hold hundreds of millions of tracks. This unparalleled access to music has not come lightly. Beginning in the 2010s, music consumers are able to purchase or subscribe to a streaming platform to gain access to a dataset of songs, readily available to them. Since the release of streaming platforms like Spotify and Apple Music, the barrier of entry to consume and release music has lowered exponentially.
#
# However, the way we consume music has also changed, with the algorithm becoming the ruling factor for many streaming platforms and social media sites. The more a song appeals to an algorithm, the more streams a song has, and all the more money it makes. This cause and effect has led to what we believe has been a homogenization of music since the streaming age began, where songs are designed for mass appeal. In this project, we’d like to explore whether or not music has become more homogenized when comparing post-streaming (2013-2026) and pre-streaming (2000-2013) eras.
# Our definition of homogeneity will include four features: energy, valence, acousticness, instrumentalness. Energy measures the "danceability" and animation of a given song, faster tempos and louder volumes connote higher scales of danceability and activity in a track, whereas softer, quieter volumes and slower tempos connote lower scales of energy. Valence describes the musical positivity, higher scales of valence include upbeat, happier, and euphoric music while lower values will include more moody, sadder, and tense musical qualities. High acousticness will include songs that sound organically produced physically by humans with instruments and lower values of acousticness will include songs that sound electronically produced, including techno-music. For example, more electronic music highlights faster tempos, which will be measured as in beats per minute (BPM). Instrumentalness highlights how many words are in a given track. A song with many lyrics will be graded lower on the instrumentalness scale, whereas tracks with mostly instrumental portions as very few lyrics and vocals will be graded higher on the scale. These four features: energy, valence, acousticness, and instrumentalness, are indicators of relative homogeneity. In our project, we would like to see if these features converge or diverge among the monthly top three Billboard Hot 100 songs during the streaming era (2013-2026) relative to the pre-streaming era (200-2012).
#
# Perhaps one of the clearest signs of how music has changed is the change in the average length of music over time, which has decreased by more than 30 seconds over time. Many of the top songs of the past few years have clocked in at under three minutes, a clear departure from longer music. This is most likely tied to the difference streaming makes when considering song structure. Researchers have found a correlation between skipping music and song structure where users are likely to skip music before the song has even made it to 30 seconds. Since streaming services only pay artists for “plays” and “plays” only count if a song has been played for longer than 30 seconds, it stands to reason that many artists and songwriters have focused their energy towards creating catchy music that’s interesting enough to capture attention, but short enough that listeners won’t get bored and skipping, leaving artists without their hard-earned revenue.
#
# In a previous study from Tilburg University, the impact of streaming services on homogenized mainstream music is mixed. In their research, Knox and Datta look at the supply and demand side of the industry, focusing on the “acoustic diversity” of a given song: the pitch, loudness, valence, tempo, and duration. In the early beginnings of platforms like Napster, an illegal music sharing platform, YouTube, and Spotify, artists were able to easily create and distribute their music to a large audience in a way that had not been seen before. Musicians tended to mimic each other in the early stages of the new widespread distribution of music, leading to an initial decrease in diversity in music quality. However, when streaming services like Spotify became more popularized, algorithms in place were able to provide new recommendation systems and search tools that enabled listeners to discover a vast amount of music readily available to them. From a demand standpoint, consumers have more choices of music selection available to them, thus allowing for more diversity within their consumption.
#
# Despite the initial dip in acoustic diversity, there has been a weak, steady increase in acoustic diversity since the release of streaming platforms due to the large catalog of recorded music available. However, our project is looking to see if special media platforms like TikTok or Instagram influence the homogeneity of music selections within streaming platforms. We aim to explore this topic by focusing on the categorization of songs through factors such as tempo, lyrics, etc, that were on the Billboard Top 100 over the last 60-70 years. Through our exploration and analysis of this data, we hope to discover whether streaming has truly homogenized popular music or if streaming has had little to no effect on the variability of popular music.
#
# ^ Rosenblatt, Bill. “Streaming Is Changing the Sound of Music.” The Wall Street Journal, 15 Sept. 2023, www.wsj.com/arts-culture/music/streaming-is-changing-the-sound-of-music-182dc907?gaa_at=eafs&gaa_n=AWEtsqfipow1GoFn2kJm7IBA7Gz4TYoUnk-sSGEj-DU5EpPTInPq82ZxQwundm4CAOg%3D&gaa_ts=6983c67b&gaa_sig=l3vMKS7DG8OgIs-7w4HPTc6jkRjV7wPNkNWGRtGIdoiv5nR9ZQakPh5m8NDaYWNwG5YKd7nUowkS270C-9jYhg%3D%3D. Accessed 4 Feb. 2026.
# ^ Montecchio, Nicola, et al. “The Skipping Behavior of Users of Music Streaming Services and Its Relation to Musical Structure.” PLOS ONE, edited by Jichang Zhao, vol. 15, no. 9, Sept. 2020, p. e0239418, https://doi.org/10.1371/journal.pone.0239418.
# ^ Knox, G., & Datta, H. (2020). Streaming Services and the Homogenization of Music Consumption.

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We hypothesize that songs from the years 2013-2026, which would be considered the streaming era, will exhibit less variability in measurable factors such as danceability, energy valence, acousticness, instrumentalness, tempo, duration, loudness, key/mode, explicitness, and speechness when comparing them to songs from 2000-2012, which would be the pre-streaming era. This would indicate that popular songs over the years have become more homogenized. This could be for a wide variety of reasons, but we theorize that it is largely because of two reasons. The first is because of corporate involvement with music creation. Music corporations want to maximize profits and popularity of an artist's music, which makes them push for their artists to create music that is broader, more generic, and more formulaic, which has led popular songs to sound more similar in recent years. This is compounded by the second cause, the rise of streaming services. Streaming services are operated as a business that pits artists against each other in a popularity contest. More streams mean an artist's music is pushed out more, which means more money for the artist and exponentially more for the business. This also encourages streaming services to promote music that appeals to the broadest audience, as it generates the most revenue for them.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# - Dataset #1:
#   - Dataset Name: 160k Spotify songs from 1921 to 2020 (Sorted)
#   - Link to the dataset: https://github.com/fcpercival/spotify-data-sorted
#   - Number of observations: 160,000+
#   - Number of variables: 12
#   - Description of the variables most relevant to this project:
#     Danceability (unitless, 0–1) estimates how suitable a track is for dancing.
#     Energy (0–1) measures intensity and activity.
#     Valence (0–1) describes musical positivity.
#     Acousticness (0–1) estimates the likelihood a track is acoustic rather than electronically produced.
#     Instrumentalness (0–1) predicts whether a track contains vocals
#     Tempo is measured in beats per minute (BPM)
#     Duration is given in milliseconds; dividing by 1000 converts to seconds.
#     Loudness is measured in decibels (dB)
#     Key is encoded as an integer 0–11 representing the 12 pitch classes (C through B)
#         Mode indicates major (1) or minor (0).
#     Speechiness (0–1) measures the presence of spoken words
#   - Descriptions of any shortcomings this dataset has with repsect to the project:
#     Dataset doesnt have data past 2020 and can reflect biases from Spotify's reccomendation algorithms.
#
#
# - Dataset #2
#   - Dataset Name: Hit Songs Prediction Dataset
#   - Link to the dataset: https://github.com/Orfium/hsp-lyrics-dataset?tab=readme-ov-file
#   - Number of observations: ~12,000
#   - Number of variables: 8 relevant
#   - Description of the variables most relevant to this project:
#     Danceable, alternative, electronic, pop, aggressive, happy, bright, and instrumental. All measured on a scale from 0-1. Indications of genre and mood surrounding the song.
#   - Descriptions of any shortcomings this dataset has with repsect to the project:
#     Does not include any data from past 2010, which does not include the post streaming era we intend to target.
#
# - Dataset #3
#   - Dataset Name: BillBoard Hot100
#   - Link to the dataset: https://www.kaggle.com/datasets/ludmin/billboard?select=hot100.csv
#   - Number of observations: ~350,000
#   - Number of variables: 7
#   - Description of the variables most relevant to this project:
#     chart_week = date/week of the chart.
#     this_week = rank that week.
#     title = song name.
#     performer = artist name.
#     last_week = rank previous week.
#     peak_pos = highest rank reached.
#     wks_on_chart = weeks on the Hot 100 chart.
#   - Descriptions of any shortcomings this dataset has with repsect to the project: Only includes Billboard's rankings, which are mainstream media centralized to the United States and North America.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://raw.githubusercontent.com/FCPercival/spotify-data-sorted/refs/heads/master/data.csv', 'filename':'music-data.csv'
    },
]

# %% [markdown]
# # Dataset #1: 160K Spotify Songs (1921-2020)
#
# https://github.com/fcpercival/spotify-data-sorted
#
# The 160K Spotify Songs (1921–2020) is a large music metadata collection derived from Spotify’s Web API. It contains roughly 160,000 tracks and includes artist information, genre labels, release year, and several audio features.
#
# The most important metrics are Spotify’s audio features, which are standardized numeric descriptors. Danceability (unitless, 0–1) estimates how suitable a track is for dancing. Values closer to 1 indicate more danceable songs. Energy (0–1) measures intensity and activity; higher values correspond to louder and faster tracks. Valence (0–1) describes musical positivity. Higher values sound happier or more euphoric, while lower values tend to sound sadder or more tense. Acousticness (0–1) estimates the likelihood a track is acoustic rather than electronically produced. Instrumentalness (0–1) predicts whether a track contains vocals; values above ~0.5 suggest mostly instrumental music. These features are probabilities or model outputs rather than physical measurements, so they are relative indicators rather than exact physical quantities.
#
# Several features are expressed in real physical units. Tempo is measured in beats per minute (BPM); most contemporary pop songs fall roughly between 90–130 BPM, while extreme values (e.g., >200 BPM) indicate very fast genres like speed metal or certain electronic styles. Duration is given in milliseconds; dividing by 1000 converts to seconds. Loudness is measured in decibels (dB), typically ranging from about −60 dB (very quiet) to 0 dB (maximum digital level). Key is encoded as an integer 0–11 representing the 12 pitch classes (C through B), and mode indicates major (1) or minor (0). Speechiness (0–1) measures the presence of spoken words; values above ~0.66 are likely spoken word (e.g., podcasts, rap verses heavy in speech), while values below ~0.33 are more purely musical. These metrics allow analysis of musical style, mood, production trends, and historical changes over time.
#
# The primary concern with bias in this dataset is derived from the fact that the data is taken from Spotify’s catalog and recommendation algorithms, meaning it reflects Spotify’s licensing agreements and popularity trends, not a perfectly representative sample of all music ever recorded. Earlier decades (e.g., 1920s–1950s) are likely underrepresented and skewed toward recordings that have been digitized and re-released, which may also show biases. Furthermore, the data does not consist of music from 2020-2026, which is a large segment of the time period we are analyzing for post-streaming.

# %%
import pandas as pd
import os
from sklearn.preprocessing import StandardScaler

df = pd.read_csv("data/00-raw/music-data.csv")
drops = ['liveness', 'popularity']
df = df.drop(columns=drops)
print(df.columns)
print(df.isnull().sum())

df["duration_min"] = df["duration_ms"] / 60000
df = df.drop(columns=["duration_ms"])

features = [
    "acousticness",
    "danceability",
    "energy",
    "instrumentalness",
    "loudness",
    "speechiness",
    "tempo",
    "valence",
    "duration_min"
]

#normalize data based on difference from mean
#eg: 0 = average tempo, +1 = 1 std above mean, −1 = 1 std below mean
X =  df[features].copy()
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_scaled_df = pd.DataFrame(X_scaled, columns=features)
df[features] = X_scaled_df

df.head()

folder_name = 'data/01-interim'
file_name = 'filtered_feature_map.csv'
full_path = os.path.join(folder_name, file_name)

if not os.path.exists(folder_name):
    os.makedirs(folder_name, exist_ok=True)

df.to_csv(full_path, index=False)

df
# Out:
# Index(['id', 'name', 'artists', 'duration_ms', 'release_date', 'year',
#        'acousticness', 'danceability', 'energy', 'instrumentalness',
#        'loudness', 'speechiness', 'tempo', 'valence', 'mode', 'key',
#        'explicit'],
#       dtype='object')
# id                  0
# name                0
# artists             0
# duration_ms         0
# release_date        0
# year                0
# acousticness        0
# danceability        0
# energy              0
# instrumentalness    0
# loudness            0
# speechiness         0
# tempo               0
# valence             0
# mode                0
# key                 0
# explicit            0
# dtype: int64
#                             id  \
# 0       0gNNToCW3qjabgTyBSjt3H
# 1       0tMgFpOrXZR6irEOLNWwJL
# 2       2ZywW3VyVx6rrlrX75n3JB
# 3       6DdWA7D1o5TU2kXWyCLcch
# 4       3vMmwsAiLDCfyc1jl76lQE
# ...                        ...
# 169902  4KiYPYpm4ultIp247ftPlI
# 169903  42tFTth2jcF7iSo0RBjfJF
# 169904  6XP9L7di5JnOc9WaeAW8oe
# 169905  3Gpdzw72aBVJSrm5J1leVK
# 169906  2p5DfmIUTLH79elmaSCCR5
#
#                                                      name  \
# 0                               !Que Vida! - Mono Version
# 1                                                    "40"
# 2                                             "40" - Live
# 3                                  "40" - Remastered 2008
# 4                                  "40" - Remastered 2008
# ...                                                   ...
# 169902                                 텅 빈 마음 Empty Heart
# 169903                                     피카부 Peek-A-Boo
# 169904                                     행복 (Happiness)
# 169905  헤어지지 못하는 여자, 떠나가지 못하는 남자 Can't Breakup Girl, C...
# 169906                화려하지 않은 고백 Confession Is Not Flashy
#
#                         artists release_date  year  acousticness  \
# 0                      ['Love']      11/1/66  1966      0.084389
# 1                        ['U2']      2/28/83  1983     -0.704189
# 2                        ['U2']      8/20/83  1983     -1.044579
# 3                        ['U2']      2/28/83  1983     -0.818360
# 4                        ['U2']      2/28/83  1983     -0.818360
# ...                         ...          ...   ...           ...
# 169902       ['LEE SEUNG HWAN']     10/15/89  1989     -0.170505
# 169903           ['Red Velvet']     11/17/17  2017     -1.079096
# 169904           ['Red Velvet']       8/1/14  2014     -0.451950
# 169905  ['Leessang', 'Jung In']      10/6/09  2009     -0.911291
# 169906       ['LEE SEUNG HWAN']       9/1/93  1993     -0.120057
#
#         danceability    energy  instrumentalness  loudness  speechiness  \
# 0           0.352754  0.192262         -0.513657 -0.076355    -0.408559
# 1          -0.970359 -0.032130          1.762074 -0.041415    -0.423232
# 2          -1.517854  0.730801         -0.476641  0.289814    -0.290510
# 3          -0.953250  0.210961          1.357973  0.362695    -0.422565
# 4          -0.953250  0.210961          1.357973  0.362695    -0.422565
# ...              ...       ...               ...       ...          ...
# 169902      0.050491 -0.690344         -0.523517 -0.521582    -0.403223
# 169903      1.715788  1.546089         -0.515208  1.369087    -0.269835
# 169904      1.077044  1.430153         -0.523497  1.459614     0.426455
# 169905     -0.086383  1.317958         -0.523517  1.564436     1.580268
# 169906      1.156887 -0.406115         -0.520895  0.323166    -0.437237
#
#            tempo   valence  mode  key  explicit  duration_min
# 0       0.291280  0.056816     1    9         0     -0.089407
# 1       1.081074 -0.739660     1    8         0     -0.606379
# 2       0.850430 -0.964503     1    8         0     -0.042920
# 3       1.085956 -0.846365     1    8         0     -0.607805
# 4       1.085956 -0.846365     1    8         0     -0.607805
# ...          ...       ...   ...  ...       ...           ...
# 169902 -1.392387 -1.429431     0   11         0      0.152371
# 169903 -0.064922  0.407418     0    1         0     -0.349130
# 169904  0.146130  0.567475     0   10         0     -0.085888
# 169905  1.853587 -0.568170     0   10         0      0.438667
# 169906 -0.487417 -1.021666     1    2         0     -0.005556
#
# [169907 rows x 17 columns]

# %% [markdown]
# ### Dataset #2: Hit Songs Prediction Dataset
#
# https://github.com/Orfium/hsp-lyrics-dataset?tab=readme-ov-file
#
# This dataset contains data about audio features of certain songs that charted on the BillBoard Hot100 from 1942-2010. When filtering the data based on year (2000-2026), it became apparent that the dataset was missing values from what would become our "post-streaming (2013-2026)" dataset. For that reason, in order to obtains a more comprehensive dataset of BillBoard ranked songs, we filtered the BillBoard Hot100 dataset from Kaggle (described in Dataset #3). However, this dataset still has useful information about audio features for songs that ranked between 2000-2010, that could be useful when carrying out our analysis. Namely relevant features include: danceable, alternative, electronic, pop, aggressive, happy, bright, and instrumental. These features were measured on a scale from 0-1.

# %%
import os

if not os.path.exists("data/00-raw/hsp_lyrics_dataset.tar.gz"):
    # !wget -P data/00-raw https://orfium-research-papers.s3.amazonaws.com/hit-song-prediction-dataset/hsp_lyrics_dataset.tar.gz

if not os.path.exists("data/00-raw/hsp_dataset"):
    # !tar -xvzf data/00-raw/hsp_lyrics_dataset.tar.gz -C data/00-raw/

import pandas as pd

hits = pd.read_csv("data/00-raw/hsp_dataset/hsp_hits.csv")
high_level_hits = pd.read_csv("data/00-raw/hsp_dataset/high_level_hits.csv")
display(hits.columns)
display(hits.head())
display(hits.isna().sum())
display(high_level_hits.columns)
display(high_level_hits.head())
display(high_level_hits.isna().sum())
# Out:
# Index(['msd_id', 'echo_nest_id', 'ARTIST', 'TITLE', 'year', 'peak', 'weeks'], dtype='object')
#                msd_id        echo_nest_id             ARTIST  \
# 0  TRMMWJS12903CBB7F5  SOLBDWO12AB0188CC2          Aerosmith
# 1  TRMMRUB12903CA097C  SOGDEWJ12AB0184C06       Brook Benton
# 2  TRMMFIS128E078EDEA  SOYURIX12A6701E960          Aerosmith
# 3  TRMMPDJ128F429472E  SOJWEBW12A8C13AEEC  Little River Band
# 4  TRMMUIL128F1463720  SOSRKLH12CF5F88723       Eric Clapton
#
#                             TITLE  year  peak  weeks
# 0  Remember (Walking In The Sand)  1979     6     67
# 1                       Lie To Me  1986    10     13
# 2                          Cryin'  1993    26     12
# 3              Help Is On Its Way  1980    22     14
# 4                  After Midnight  1970    12     18
# msd_id          0
# echo_nest_id    0
# ARTIST          0
# TITLE           0
# year            0
# peak            0
# weeks           0
# dtype: int64
# Index(['msd_id', 'danceable', 'female', 'alternative', 'blues', 'electronic',
#        'folkcountry', 'funksoulrnb', 'jazz', 'pop', 'raphiphop', 'rock',
#        'ambient', 'dnb', 'house', 'techno', 'trance', 'cla', 'dan', 'hip',
#        'jaz', 'pop.1', 'rhy', 'roc', 'spe', 'blu', 'cla.1', 'cou', 'dis',
#        'hip.1', 'jaz.1', 'met', 'pop.2', 'reg', 'roc.1', 'ChaChaCha',
#        'acoustic', 'aggressive', 'electronic.1', 'happy', 'not_party',
#        'not_relaxed', 'not_sad', 'Cluster1', 'Cluster2', 'Cluster3',
#        'Cluster4', 'Cluster5', 'bright', 'atonal', 'instrumental'],
#       dtype='object')
#                msd_id  danceable    female  alternative     blues  electronic  \
# 0  TRMMWJS12903CBB7F5   0.528196  0.214136     0.076715  0.088353    0.094057
# 1  TRMMRUB12903CA097C   0.982040  0.972055     0.057513  0.129689    0.162842
# 2  TRMMFIS128E078EDEA   0.313940  0.052508     0.248732  0.034915    0.030114
# 3  TRMMPDJ128F429472E   0.300077  0.267567     0.095285  0.191411    0.032080
# 4  TRMMUIL128F1463720   0.178557  0.313151     0.084556  0.061396    0.014255
#
#    folkcountry  funksoulrnb      jazz       pop  ...  not_relaxed   not_sad  \
# 0     0.127020     0.067153  0.057225  0.052493  ...     0.780863  0.689657
# 1     0.162846     0.011860  0.025092  0.100032  ...     0.314300  0.578807
# 2     0.054675     0.006778  0.014800  0.155980  ...     0.989100  0.720970
# 3     0.268002     0.026606  0.207616  0.099850  ...     0.245614  0.134404
# 4     0.276597     0.010919  0.029266  0.086664  ...     0.745764  0.784257
#
#    Cluster1  Cluster2  Cluster3  Cluster4  Cluster5    bright    atonal  \
# 0  0.110400  0.253374  0.175422  0.328600  0.132204  0.909691  0.101535
# 1  0.121474  0.118074  0.591957  0.122679  0.045816  0.087996  0.931372
# 2  0.210789  0.180598  0.450649  0.083385  0.074579  0.995537  0.020812
# 3  0.107497  0.122557  0.640115  0.119482  0.010349  0.959430  0.454213
# 4  0.274149  0.272222  0.199427  0.204986  0.049216  0.999994  0.001774
#
#    instrumental
# 0      0.162628
# 1      0.000347
# 2      0.003392
# 3      0.019033
# 4      0.011261
#
# [5 rows x 51 columns]
# msd_id          0
# danceable       0
# female          0
# alternative     0
# blues           0
# electronic      0
# folkcountry     0
# funksoulrnb     0
# jazz            0
# pop             0
# raphiphop       0
# rock            0
# ambient         0
# dnb             0
# house           0
# techno          0
# trance          0
# cla             0
# dan             0
# hip             0
# jaz             0
# pop.1           0
# rhy             0
# roc             0
# spe             0
# blu             0
# cla.1           0
# cou             0
# dis             0
# hip.1           0
# jaz.1           0
# met             0
# pop.2           0
# reg             0
# roc.1           0
# ChaChaCha       0
# acoustic        0
# aggressive      0
# electronic.1    0
# happy           0
# not_party       0
# not_relaxed     0
# not_sad         0
# Cluster1        0
# Cluster2        0
# Cluster3        0
# Cluster4        0
# Cluster5        0
# bright          0
# atonal          0
# instrumental    0
# dtype: int64

# %%
hits_filtered = hits[
    (hits["year"].between(2000, 2026)) &
    (hits["peak"].between(1, 3))
]
hits_filtered.shape
# Out:
# (96, 7)

# %%
display(hits["year"].min())
display(hits["year"].max())
# Out:
# 1942
# 2010

# %%
hits_2000_2013 = hits_filtered[
    (hits_filtered["year"] >= 2000) &
    (hits_filtered["year"] <= 2013)
]

hits_2000_2013.shape
# Out:
# (96, 7)

# %%
hits_2013_2026 = hits_filtered[
    (hits_filtered["year"] > 2013) &
    (hits_filtered["year"] <= 2026)
]
hits_2013_2026.shape
# Out:
# (0, 7)

# %%
hits_2000_2013.to_csv("data/02-processed/hsp_hits_2000_2013.csv", index=False)
hits_2013_2026.to_csv("data/02-processed/hsp_hits_2013_2026.csv", index=False)

# %% [markdown]
# ### Dataset #3: BillBoard Hot100 Dataset
#
# https://www.kaggle.com/datasets/ludmin/billboard?select=hot100.csv
#
# This dataset comprises comprehensive data about every song that has ever charted on the BillBoard Hot100 (since 1958), including song title, artist, rank (from 1-100), position peaked on the Hot100 (from 1-100), number of weeks on the Hot 100, date the song got ranked on the chart, and the song's release date. This dataset is the most up-to-date one of BillBoard chart data, but instead of going up to January/February 2026, its last recorded data ends at October 2025. For the purposes of this data analysis, however, we will generalize the conclusions from song post 2014 to October 2025 to be part of our "post-streaming (2013-2026)" dataset, due to the large size of the dataset compared to the relatively small time period of missing values.
#
# The dataset has been filtered below for the appropriate years (2000-2026), and divided into separate dataframes (hot100_2000_2013_sorted, and hot100_2014_2026_sorted) sorted based on year, month, and chart rank. It contains 2190 data points for songs charted between 2000-2013, and 1851 data points for songs charted between 2014-2026. This accounts for the fact that more than three songs chart in the top three ranks in any given month. There are no missing or null values recorded for any songs.

# %%
# !pip install kagglehub[pandas-datasets]
import kagglehub

kagglehub.dataset_download(
    "ludmin/billboard",
    path="hot100.csv",
    output_dir="./data/00-raw"
)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: kagglehub[pandas-datasets] in /home/athakur/.local/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in /home/athakur/.local/lib/python3.11/site-packages (from kagglehub[pandas-datasets]) (0.1.15)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from kagglehub[pandas-datasets]) (24.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from kagglehub[pandas-datasets]) (6.0.1)
# Requirement already satisfied: requests in /home/athakur/.local/lib/python3.11/site-packages (from kagglehub[pandas-datasets]) (2.32.5)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from kagglehub[pandas-datasets]) (4.66.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from kagglehub[pandas-datasets]) (2.2.3)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.11/site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub[pandas-datasets]) (4.25.3)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas->kagglehub[pandas-datasets]) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->kagglehub[pandas-datasets]) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->kagglehub[pandas-datasets]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->kagglehub[pandas-datasets]) (2024.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->kagglehub[pandas-datasets]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->kagglehub[pandas-datasets]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->kagglehub[pandas-datasets]) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->kagglehub[pandas-datasets]) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->kagglehub[pandas-datasets]) (1.16.0)
# './data/00-raw/hot100.csv'

# %%
import pandas as pd
hot100 = pd.read_csv("data/00-raw/hot100.csv")
hot100["release_date"] = pd.to_datetime(hot100["Date"])

hot100["year"] = hot100["release_date"].dt.year
hot100["month"] = hot100["release_date"].dt.month

hot100_filtered = hot100[
    (hot100["year"].between(2000, 2026)) &
    (hot100["Rank"].between(1, 3))
]
display(hot100_filtered.shape)
display(hot100.isna().sum())
# Out:
# /tmp/ipykernel_2675/2927359384.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   hot100 = pd.read_csv("data/00-raw/hot100.csv")
# (4041, 11)
# Date               0
# Song               0
# Artist             0
# Rank               0
# Last Week          0
# Peak Position      0
# Weeks in Charts    0
# Image URL          0
# release_date       0
# year               0
# month              0
# dtype: int64

# %%
hot100_2000_2013 = hot100_filtered[hot100_filtered["year"] <= 2013]
hot100_2000_2013.shape
# Out:
# (2190, 11)

# %%
hot100_2014_2026 = hot100_filtered[hot100_filtered["year"] >= 2014]
hot100_2014_2026.shape
# Out:
# (1851, 11)

# %%
hot100_2000_2013_sorted = hot100_2000_2013.sort_values(
    by=["year", "month", "Rank"]
)

hot100_unique_00_13 = (hot100_2000_2013_sorted.drop_duplicates(subset=["Song", "Artist"], keep="first")).copy()
hot100_unique_00_13
# Out:
#               Date                      Song                        Artist  \
# 216087  2000-01-05                    Smooth  Santana Featuring Rob Thomas
# 216187  2000-01-12         What A Girl Wants            Christina Aguilera
# 216387  2000-01-26        I Knew I Loved You                 Savage Garden
# 216088  2000-01-05               Back At One                Brian McKnight
# 216089  2000-01-05  I Wanna Love You Forever               Jessica Simpson
# ...            ...                       ...                           ...
# 287489  2013-09-11                   Berzerk                        Eminem
# 287589  2013-09-18                    Royals                         Lorde
# 288488  2013-11-20               The Monster      Eminem Featuring Rihanna
# 288888  2013-12-18                    Timber       Pitbull Featuring Ke$ha
# 288889  2013-12-18            Counting Stars                   OneRepublic
#
#         Rank Last Week  Peak Position Weeks in Charts Image URL release_date  \
# 216087     1         1              1              24         #   2000-01-05
# 216187     1        11              1               8         #   2000-01-12
# 216387     1         2              1              15         #   2000-01-26
# 216088     2         2              2              20         #   2000-01-05
# 216089     3         3              3              13         #   2000-01-05
# ...      ...       ...            ...             ...       ...          ...
# 287489     3         3              1               -         #   2013-09-11
# 287589     3         8              3              10         #   2013-09-18
# 288488     2         3              2               2         #   2013-11-20
# 288888     2         4              2               9         #   2013-12-18
# 288889     3         5              3              25         #   2013-12-18
#
#         year  month
# 216087  2000      1
# 216187  2000      1
# 216387  2000      1
# 216088  2000      1
# 216089  2000      1
# ...      ...    ...
# 287489  2013      9
# 287589  2013      9
# 288488  2013     11
# 288888  2013     12
# 288889  2013     12
#
# [354 rows x 11 columns]

# %%
hot100_2014_2026_sorted = hot100_2014_2026.sort_values(
    by=["year", "month", "Rank"]
)

hot100_unique_14_26 = (hot100_2014_2026_sorted.drop_duplicates(subset=["Song", "Artist"], keep="first")).copy()
hot100_unique_14_26
# Out:
#               Date                 Song  \
# 289087  2014-01-01          The Monster
# 289287  2014-01-15               Timber
# 289288  2014-01-15       Counting Stars
# 289488  2014-01-29           Dark Horse
# 289688  2014-02-12        Drunk In Love
# ...            ...                  ...
# 350587  2025-10-15  The Fate Of Ophelia
# 350588  2025-10-15              Opalite
# 350389  2025-10-01             Soda Pop
# 350489  2025-10-08          Tit For Tat
# 350589  2025-10-15     Elizabeth Taylor
#
#                                                    Artist  Rank Last Week  \
# 289087                           Eminem Featuring Rihanna     1         1
# 289287                            Pitbull Featuring Ke$ha     1         2
# 289288                                        OneRepublic     2         3
# 289488                       Katy Perry Featuring Juicy J     2         4
# 289688                            Beyonce Featuring Jay Z     2        13
# ...                                                   ...   ...       ...
# 350587                                       Taylor Swift     1         1
# 350588                                       Taylor Swift     2         2
# 350389  Saja Boys: Andrew Choi| Neckwav| Danny Chung| ...     3         5
# 350489                                         Tate McRae     3         3
# 350589                                       Taylor Swift     3         3
#
#         Peak Position Weeks in Charts Image URL release_date  year  month
# 289087              1               8         #   2014-01-01  2014      1
# 289287              1              13         #   2014-01-15  2014      1
# 289288              2              29         #   2014-01-15  2014      1
# 289488              2              18         #   2014-01-29  2014      1
# 289688              2               7         #   2014-02-12  2014      2
# ...               ...             ...       ...          ...   ...    ...
# 350587              1               -         #   2025-10-15  2025     10
# 350588              1               -         #   2025-10-15  2025     10
# 350389              3              13         #   2025-10-01  2025     10
# 350489              1               -         #   2025-10-08  2025     10
# 350589              1               -         #   2025-10-15  2025     10
#
# [292 rows x 11 columns]

# %%
hot100_unique_00_13.to_csv("data/02-processed/bb_hot100_2000_2013.csv", index=False)
hot100_unique_14_26.to_csv("data/02-processed/bb_hot100_2014_2026.csv", index=False)

# %% [markdown]
# Dataset 1: Spotify 160K Cleanup Continued

# %%
#artist cleanup
import re

def normalize_artists(artist_string):
    if pd.isna(artist_string):
        return artist_string
    
    # lowercase
    artist_string = artist_string.lower()
    
    # replace common separators with comma
    artist_string = re.sub(r'featuring|feat\.?|with|&| x ', ',', artist_string)
    
    # remove extra spaces around commas
    artist_string = re.sub(r'\s*,\s*', ',', artist_string)
    
    # remove multiple commas
    artist_string = re.sub(r',+', ',', artist_string)
    
    # split into list
    artist_list = artist_string.split(',')
    
    # strip whitespace
    artist_list = [a.strip() for a in artist_list if a.strip()]
    
    # OPTIONAL: sort alphabetically for consistent matching
    artist_list = sorted(artist_list)
    
    # rejoin
    return ",".join(artist_list)

# %%
#apply artist cleaning
feature_df = pd.read_csv('data/01-interim/filtered_feature_map.csv')
feature_df["artists_norm"] = feature_df["artists"].apply(normalize_artists)
feature_df.drop(columns=["artists"])

hot100_unique_00_13["artists_norm"] = hot100_unique_00_13["Artist"].apply(normalize_artists)
hot100_unique_00_13.drop(columns=["Artist"])

hot100_unique_14_26["artists_norm"] = hot100_unique_14_26["Artist"].apply(normalize_artists)
hot100_unique_14_26.drop(columns=["Artist"])
# Out:
#               Date                 Song  Rank Last Week  Peak Position  \
# 289087  2014-01-01          The Monster     1         1              1
# 289287  2014-01-15               Timber     1         2              1
# 289288  2014-01-15       Counting Stars     2         3              2
# 289488  2014-01-29           Dark Horse     2         4              2
# 289688  2014-02-12        Drunk In Love     2        13              2
# ...            ...                  ...   ...       ...            ...
# 350587  2025-10-15  The Fate Of Ophelia     1         1              1
# 350588  2025-10-15              Opalite     2         2              1
# 350389  2025-10-01             Soda Pop     3         5              3
# 350489  2025-10-08          Tit For Tat     3         3              1
# 350589  2025-10-15     Elizabeth Taylor     3         3              1
#
#        Weeks in Charts Image URL release_date  year  month  \
# 289087               8         #   2014-01-01  2014      1
# 289287              13         #   2014-01-15  2014      1
# 289288              29         #   2014-01-15  2014      1
# 289488              18         #   2014-01-29  2014      1
# 289688               7         #   2014-02-12  2014      2
# ...                ...       ...          ...   ...    ...
# 350587               -         #   2025-10-15  2025     10
# 350588               -         #   2025-10-15  2025     10
# 350389              13         #   2025-10-01  2025     10
# 350489               -         #   2025-10-08  2025     10
# 350589               -         #   2025-10-15  2025     10
#
#                                              artists_norm
# 289087                                     eminem,rihanna
# 289287                                      ke$ha,pitbull
# 289288                                        onerepublic
# 289488                                 juicy j,katy perry
# 289688                                      beyonce,jay z
# ...                                                   ...
# 350587                                       taylor swift
# 350588                                       taylor swift
# 350389  saja boys: andrew choi| neckwav| danny chung| ...
# 350489                                         tate mcrae
# 350589                                       taylor swift
#
# [292 rows x 11 columns]

# %%
#the following cell cleans up the Spotify 160K database according to the sampled data 
#from the Billboard Top 100 dataset

# Spotify cleaning
feature_df["name"] = feature_df["name"].str.lower().str.strip()
feature_df["artists"] = feature_df["artists"].str.lower().str.strip()

# Billboard cleaning
hot100_unique_00_13["Song"] = hot100_unique_00_13["Song"].str.lower().str.strip()
hot100_unique_00_13["Artist"] = hot100_unique_00_13["Artist"].str.lower().str.strip()

hot100_unique_14_26["Song"] = hot100_unique_14_26["Song"].str.lower().str.strip()
hot100_unique_14_26["Artist"] = hot100_unique_14_26["Artist"].str.lower().str.strip()

features_00_13 = feature_df.merge(
    hot100_unique_00_13,
    left_on="name",
    right_on="Song",
    how="inner"
)

features_14_26 = feature_df.merge(
    hot100_unique_14_26,
    left_on="name",
    right_on="Song",
    how="inner"
)

print(features_00_13.head())
print(features_14_26.head())

features_00_13.to_csv("data/02-processed/hot100_features_00_13.csv", index=False)
features_14_26.to_csv("data/02-processed/hot100_features_14_26.csv", index=False)
# Out:
#                        id                name                   artists  \
# 0  41bIQPBE1lFN0mmw6Lmssz        21 questions  ['50 cent', 'nate dogg']
# 1  56fXFvwIGDLvWFhuZtWhrO        21 questions  ['50 cent', 'nate dogg']
# 2  6pymOcrCnMuCWdgGVTvUgP                   3        ['britney spears']
# 3  3g6SuyjGaGyAXmjvdNI1IU           4 minutes                 ['avant']
# 4  4kvdX9zzsix7jYHsRVkVUH  a moment like this        ['kelly clarkson']
#
#   release_date_x  year_x  acousticness  danceability    energy  \
# 0         2/6/03    2003     -0.372296      0.215880  1.190803
# 1         2/6/03    2003     -0.372296      0.215880  1.190803
# 2        11/9/09    2009     -1.189550      0.905952  0.824297
# 3         1/1/06    2006     -1.059448      1.653055  0.416653
# 4        4/15/03    2003     -0.876774     -0.708018  0.311937
#
#    instrumentalness  loudness  ...  \
# 0         -0.522343  1.316853  ...
# 1         -0.522343  1.316853  ...
# 2         -0.523517  1.668199  ...
# 3         -0.523517  1.048446  ...
# 4         -0.523517  1.315088  ...
#
#                                             Artist  Rank  Last Week  \
# 0                      50 cent featuring nate dogg     1          2
# 1                      50 cent featuring nate dogg     1          2
# 2                                   britney spears     1          1
# 3  madonna featuring justin timberlake & timbaland     3         68
# 4                                   kelly clarkson     1         52
#
#    Peak Position  Weeks in Charts  Image URL  release_date_y year_y month  \
# 0              1               11          #      2003-05-28   2003     5
# 1              1               11          #      2003-05-28   2003     5
# 2              1                -          #      2009-10-21   2009    10
# 3              3                2          #      2008-04-09   2008     4
# 4              1                3          #      2002-10-02   2002    10
#
#                         artists_norm_y
# 0                    50 cent,nate dogg
# 1                    50 cent,nate dogg
# 2                       britney spears
# 3  justin timberlake,madonna,timbaland
# 4                       kelly clarkson
#
# [5 rows x 30 columns]
#                        id                 name  \
# 0  1wp1aHirvZihTdrtdFuFv0       1-800-273-8255
# 1  5tz69p7tJuGPeMGwNTxYuV       1-800-273-8255
# 2  5kqIPrATaCc2LqxVWzQGbk              7 years
# 3  6ocbgoVGwYJhOv1GgI9NsF              7 rings
# 4  0ifSeVGUr7py5GggttDhXw  all about that bass
#
#                                artists release_date_x  year_x  acousticness  \
# 0                   ['our last night']        9/26/17    2017     -1.300668
# 1  ['logic', 'alessia cara', 'khalid']         5/5/17    2017      0.201215
# 2                     ['lukas graham']         4/1/16    2016     -0.547536
# 3                    ['ariana grande']         2/8/19    2019      0.262284
# 4                   ['meghan trainor']        6/30/14    2014     -1.183177
#
#    danceability    energy  instrumentalness  loudness  ...  \
# 0      0.312832  1.160884         -0.472762  0.930390  ...
# 1      0.466815  0.319417         -0.523517  0.632160  ...
# 2      1.293761 -0.058309         -0.523517  0.977859  ...
# 3      1.367901 -0.641726         -0.523517  0.112641  ...
# 4      1.556102  1.460072         -0.523511  1.349322  ...
#
#                                   Artist  Rank  Last Week  Peak Position  \
# 0  logic featuring alessia cara & khalid     3          5              3
# 1  logic featuring alessia cara & khalid     3          5              3
# 2                           lukas graham     3          5              3
# 3                          ariana grande     1          1              1
# 4                         meghan trainor     2          4              2
#
#    Weeks in Charts  Image URL  release_date_y year_y month  \
# 0               20          #      2017-09-27   2017     9
# 1               20          #      2017-09-27   2017     9
# 2                9          #      2016-03-30   2016     3
# 3                -          #      2019-01-30   2019     1
# 4                6          #      2014-08-27   2014     8
#
#               artists_norm_y
# 0  alessia cara,khalid,logic
# 1  alessia cara,khalid,logic
# 2               lukas graham
# 3              ariana grande
# 4             meghan trainor
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Ethics

# %% [markdown]
# ## Ethics
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [ ] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
# > Because we are only looking at the top 3 Billboard Hot 100 songs, selection bias may occur due to factors such as audience preference, popularity, and marketing power. Selection bias will lean towards successful artists and popularized genres that hold these factors, making the scope of songs analyzed less diverse because we will be excluding various genres that are less popular and more niche.
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
# > The data that will be analyzed in this project comes from publicly available Billboard Hot 100 chart information. The analysis focuses only on the top three songs per period and does not collect or use any personal or private data. As a result, there is no exposure of personally identifiable information.
#  - [ ] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [ ] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  - [ ] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [ ] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
# > Since we will be analyzing the Billboard Hot 100 chart and more specifically the top 3 songs of the chart, it is likely that the top 3 songs will have alike genres, audiences, and artists. This results in the analysis overlooking qualitative factors that play a role in music like culture, sociopolitical influences, and artistic expression that quantitative factors fail to capture. This fails to include the analysis of songs and genres who do not qualify as mainstream charting music.
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
# > The Billboard Hot 100 chart is composed of songs that are most popular in the U.S. that  lead to geographic and cultural biases in the dataset. This overrepresentation of U.S. trends in music affects the conclusion being made about musical homogenization because it excludes global trends, artists, and listening patterns in music that is not part of mainstream U.S. music
#  - [ ] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
# > The analysis conducted to form a response to the research question is based solely on songs and music trends that are publicly shared and are not focused on private individuals.
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
# > The analysis includes data sources that are traceable and can be accessed by anyone who later on wishes to analyze it too. The well documented data also includes preprocessing steps and analytical methods that are used to reach a conclusion. Together this project can be reanalyzed by later on researchers, allowing them to either replicate results or identify potential errors.
#
# ### D. Modeling
#  - [ ] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  - [ ] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
# > The variables that will be used to measure similarities over the years are mainly audio based such as tempo, danceability, and instrumentals. We do not include other factors such as emotion and cultural significance which can also affect our conclusion.
#  - [ ] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
# > As previously stated, the data sets are limited to U.S. music trends, mainstream songs, quantitative features and exclude niche genres, cultural and emotional significance, and qualitative features.
#
# ### E. Deployment
#  - [ ] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
# > Since the project only focuses on the composition of songs and analyzes factors that observe how songs are homogenized throughout the years,no users will be directly harmed with the results of the model, making redress in inapplicable.
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
# > Looking to see if songs have become more homogenized over the years, there is the possibility that people may use the results of the model to criticize mainstream songs and popular genres of music. We acknowledge some may use the results of the model to target artists or nowadays popular music and will work carefully and respectfully to form a carefully presented analysis and conclusion, focusing on limitations and avoiding judgement to artists and their music.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# * Communicate with rest of the team members within at most twelve hours of initial communication.
# * Be open to everyone's ideas and inputs and make decisions based on maximum benefit to the project.
# * Members with more experience with Git, data analysis and/or data visualization will assist members with less experience, so everyone is on the same page and understands how to contribute to the project.
# * Tasks are divided evenly so that no one is taking on too much work, even if that means some members specialize in some tasks more than others.
# * Members will meet once either in-person or online before important deadlines/checkpoints to make sure that project is on track.
# * Should a conflict of interest arise, members will resolve it respectfully and not deter the progress of the project.

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 2/11  |  3:30 PM | Planning Project Proposal Sections  | All members will communicate with each other to complete their sections of the Project Proposal. |
# | 2/18  |  3:30 PM |  Edit, finalize, and submit proposal; search for datasets | Discuss wrangling and assign parts for the data visualization. Complete data checkpoint. |
# | 2/25  | 3:30 PM  | Import and Wrangle Data   | Discuss wrangling and analytical approaches; Assign group members to lead each specific part |
# | 3/4  | 3:30 PM  | Edit and Finalize Analysis | Members will finalize the analysis and assign parts for results/conclusion/discussion. Two members will start working on the video component.    |
# | 3/11  | 3 PM  | Finalize all components of the Project, including the video portion. | Discuss/edit full project |
# | 3/18  | 3 PM  | Proofread/Overlook Project| Turn in Project by 11:59. |
